# %% [markdown]
# ## CCNA 200-301 VOLUME 1 translate
# [](#)
# [general](#general)
# [page list](#page-list)
# [clear one file](#clear-one-file)
# [](#)
# [tests](#tests)
# [footer](#footer)
# [](#)
# [](#)
# [](#)

# %% [markdown]
# ## general

# %%
from googletrans import Translator, constants
from pprint import pprint
# init the Google API translator
translator = Translator()

def translate(text):
    translation = translator.translate(text, src="en", dest="ru")
#     print(f"{translation.origin} ({translation.src}) --> {translation.text} ({translation.dest})")    return translation
    return translation.text

text = "This is a pen."    
translation = translate(text)   
print(translation)

def mReadFile(nameFile):
    s = ''
    with open(nameFile, encoding="utf8") as file:
        s = file.read()
    return s

def mWriteFile(nameFile, s):
    with open(nameFile, 'w', encoding="utf8") as file:
        file.write(s)
    return 

def translateListSmall(lien):
    sen = '\n'.join(lien)
    sru = translate(sen)
    liru = sru.split('\n')
    lienru = []
    for i in range(len(liru)):
        lienru.append(f'{lien[i]}|{liru[i]}')
    return lienru

def mList(s, l):
    '''
    s1\ns2 => [s1, s2]
    '''
    l2 = s.split('\n')
    l2 = list(map(lambda x: x.strip(), l2))
    for e in l2:
        l.append(e)
    pass


l = ['hello' , 'world']
l2 = translateListSmall(l)
print(l)
print(l2)
# Out:
# Это ручка.
# ['hello', 'world']
# ['hello|Здравствуйте', 'world|Мир']

# %% [markdown]
# ## page list
# ```
# [1](#1)
# [2](#2)
# [3](#3)
# ## 1
# --|--
# ## 2
# --|--
# ## 3
# --|--
# ```

# %%
import re

s = mReadFile("x14a.txt")

l = s.split('\n')
l = list(filter(lambda x: len(x.strip())>0, l))
l.append('11')
lout = ['(', ')', "'", ',']
lnav = []
for e in l:
    match = re.search('^##?', e)
    e2 = ''
    e4 = ''
    e12 = ''
    if match:
        e2 = re.sub('^##?','',e)
        e2 = e2.strip()
        e4 = re.sub(' ','-',e2)
        for r in lout:
            e4 = e4.replace(r, '')
        e12 = f'[{e2}](#{e4})   '
        e12 = '1. ' + e12
        lnav.append(e12)
#         print(e12)

# l = lnav + l

ltab = []
lall = []
k = 0
for e in l:
    match1 = re.search('\[.*\]\(.*\)', e)
    match2 = re.search('^##?', e)
    if match1 or match2 or k == len(l)-1:
        if len(ltab)!=0:
            ltab = translateListSmall(ltab)
            ltab2 = []
            ltab2.append('  ')
#             ltab2.append('  ')
            ltab2.append('__|__')
            ltab2.append('--|--')
#             print(e)
            lall += ltab2 + ltab
            lall.append('   ')
            ltab = []
        if k != len(l)-1:
            lall.append(e)
    else:
#         e2 = translate(e)
#         ltab.append(f'{e}|{e2}')
        ltab.append(e)
        
    k+=1    

lnav.append('   ')    
lall = lnav + lall 

for e in lall:
#     print(e)
    pass
s2 = '\n'.join(lall)
# print(s2)
mWriteFile("x14b.txt", s2)
print(len(l), len(lall))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8e144339360d> in <module>
#       1 import re
#       2
# ----> 3 s = mReadFile("x14a.txt")
#       4
#       5 l = s.split('\n')
#
# <ipython-input-2-1bc73d5c33e8> in mReadFile(nameFile)
#      15 def mReadFile(nameFile):
#      16     s = ''
# ---> 17     with open(nameFile, encoding="utf8") as file:
#      18         s = file.read()
#      19     return s
#
# FileNotFoundError: [Errno 2] No such file or directory: 'x14a.txt'

# %% [markdown]
# ## clear one file

# %%
import re

def mDel2Str(l1, l2):
    '''
    [1,2] => [1]
    удаляется только 2-я строка
    '''
    li2Off = [['\|\|\|\|\|', '^\d+$']]
    l1.append('11')
    e0 = l1[0]
    l3 = []
    for i in range(1, len(l1)):
        e = l1[i]
        match1 = re.search(li2Off[0][0], e0)
        match2 = re.search(li2Off[0][1], e)
        if match1 and match2:
#             для 2-х строк раскомментировать
#             l3 = l3[:-1]
            pass
        else:
            l3.append(e0)
            e0 = e
    for e in l3:
        l2.append(e)
    pass


li2Off = [['\|\|\|\|\|', '^\d+$']]


liOff = ['CCNA 200-301 Official Cert Guide', 
#         'Technet24',
        'Chapter \d\d?: ',
        'This page intentionally left blank', 
        '\|\|\|\|\|'] 

def mDelStr(l1, l2):
    k = 0
    for e in l1:
        match = None
        for eOff in liOff:
            match = re.search(eOff, e)
            if match != None:
                break
        if match == None:
            l2.append(e)
        k += 1
    print(len(l1), len(l2))
    pass

def mFigure(l1, l2):
# Figure figure
    l01 = []
    k = 0
    for e in l1:
        match1 = re.search('Figure \d\d?-\d\d? [A-Z]', e)
        match2 = re.search(' \d\d+$', e)
        if match1 and match2:
            k += 1
            e = re.sub('Figure', 'figure', e)
        l01.append(e)
    
    k2 = 0
    l01.reverse()
    l02 = []
    fl = 0
    lf = []
    for e in l01:
        match1 = re.search('Figure \d\d?-\d\d? [A-Z]', e)
        if match1:
            k2 += 1
            fl = 1
        match2 = re.search('\.$', e)
        if fl > 0:
            lf.append(e)
            if match2:
                print(len(lf))
                print(lf)
                lf = []
                fl = 0
        else:
            l02.append(e)
    l02.reverse()
    print(len(l02), 33)
    for e in l02:
        l2.append(e)
    print(k, k2, len(l2))
    pass
    return k2

def mClearFile():
    s1 = mReadFile('x15cla.txt')
    s1 = s1.replace('*', '1')
    s1 = s1.replace('¦', '######')
    l1 = s1.split('\n')
    l12 = []
    print(len(l1),33)
    mDel2Str(l1, l12)
    print(len(l12), 44)
    l2 = []
    mDelStr(l12, l2)
    l3 = l2
    l2 = []
    mFigure(l3, l2)
    
    s2 = '\n'.join(l2)
    mWriteFile('x15clb.txt', s2)
    pass
    

mClearFile()
# Out:
# 43431 33
# 43189 44
# 43189 40309
# 2
# ['Figure 29-21 Configuring Management Access from Wireless Networks', 'the box to allow management sessions from any WLAN that is configured on the controller.']
# 2
# ['Figure 29-20 Displaying WLANs Configured on a Controller', 'been added as WLAN ID 1 and is enabled for use.']
# 2
# ['Figure 29-19 Configuring Advanced WLAN Settings', 'peer-to-peer blocking, client exclusion, client load limits, and so on.']
# 2
# ['Figure 29-18 Configuring QoS Settings', '###### Bronze (background).']
# 3
# ['Figure 29-17 Selecting RADIUS Servers for WLAN Authentication', 'Technet24', 'the WLAN.']
# 2
# ['Figure 29-16 Configuring Layer 2 WLAN Security', 'figure, so the WLAN will allow only WPA2-Personal with pre-shared key authentication.']
# 2
# ['Figure 29-15 Configuring the General WLAN Parameters', 'By default, the General tab is selected.']
# 2
# ['Figure 29-14 Creating a New WLAN', 'on each controller.']
# 2
# ['Figure 29-13 Displaying a List of WLANs', 'the Go button.']
# 3
# ['Figure 29-12 Editing the Dynamic Interface Parameters', 'Technet24', 'the list of interfaces.']
# 3
# ['Figure 29-11 Defining a Dynamic Interface Name and VLAN ID', 'Figure 29-10 Displaying a List of Dynamic Interfaces', 'Apply button.']
# 3
# ['Figure 29-9 Configuring a New RADIUS Server', 'Figure 29-8 Displaying the List of RADIUS Authentication Servers', 'management functions. Click Apply to complete the server configuration.']
# 10
# ['Figure 29-7 Connecting Wired and Wireless Networks with a WLAN', 'CAPWAP', '192.168.199.199/24', 'VLAN 100', 'Interface Engineering', '192.168.199.0/24', 'SSID engineering', 'WLAN VLAN', 'AP WLC', 'shown in Figure 29-7 using the WPA2-Personal (PSK) security model.']
# 15
# ['Figure 29-6 Cisco Wireless LAN Controller Interfaces', 'Management', 'Redundancy', 'VLAN x Management', 'WLAN n SSID', 'VLAN y Service Port', 'Interface', 'VLAN n Dynamic', 'Interface WLAN 1 SSID', 'Dynamic', 'AP', 'VLAN a', 'Switch', 'WLC', '###### Dynamic interface: Used to connect a VLAN to a WLAN.']
# 12
# ['Figure 29-5 Cisco Wireless LAN Controller Ports', 'CAPWAP', 'Switched Infrastructure', 'LAG', 'Console', 'Port', 'Service', 'Ports', 'Distribution', 'AP WLC', 'operation', '###### Redundancy port: Used to connect to a peer controller for high availability (HA).']
# 6
# ['Figure 29-4 The Advanced WLC Configuration GUI', 'Figure 29-3 Accessing the Advanced Configuration Interface', 'Technet24', '1 A 2 B 3 D 4 C 5 D 6 C, D 7 C 8 A, C', 'Answers to the “Do I Know This Already?” quiz:', 'work through the remainder of the chapter.']
# 2
# ['Figure 29-2 Accessing a WLC with a Web Browser', 'as you are prompted for them.']
# 11
# ['Figure 29-1 Comparing Connections to Autonomous and Lightweight APs', 'CAPWAP', 'WLC', 'Switched LAN', 'Lightweight AP', 'Access Link', 'Switched LAN', 'Autonomous AP', 'Trunk Link', 'Technet24', 'end of the tunnel, as shown in the right portion of Figure 29-1.']
# 15
# ['Figure 28-5 Checking Message Integrity over a Wireless Network', 'f7', 'f7', '741fcb64901d', 'f7', '6. Compare MICs', '5. Compute MIC', 'f7', '3. Encrypt Data + MIC 4. Decrypt nihao123 f7', '2. Compute MIC', '1. Original Data', 'nihao123', 'nihao123', 'Client AP', 'the MIC process.']
# 9
# ['Figure 28-4 Encrypting Wireless Data to Protect Data Privacy', '328A29 nihao123', '??', '??', 'nihao123', 'My password is', 'Client', 'AP', 'devices cannot.']
# 3
# ['Figure 28-3 Authenticating a Wireless AP', 'AP-1', 'Ok.']
# 3
# ['Figure 28-2 Authenticating a Wireless Client', 'AP', 'Ok.']
# 11
# ['Figure 28-1 Wireless Transmissions Reaching Unintended Recipients', 'nihao123', 'nihao123', 'His password is', 'nihao123', 'My password is', 'nihao123', 'His password is', 'Client', 'AP', 'of the wireless security framework.']
# 8
# ['Figure 27-11 WLC Location in a Mobility Express Deployment', 'Core Layer', 'Distribution Layer', 'Lightweight APs', 'Express WLC', 'Mobility', 'Access Layer', 'Express WLC can support up to 100 APs.']
# 9
# ['Figure 27-10 WLC Location in an Embedded Deployment', 'Core Layer', 'Distribution Layer', 'Lightweight APs', 'Embedded WLC', 'Access Layer', '27', 'Technet24', 'the site.']
# 8
# ['Figure 27-9 WLC Location in a Cloud-based Deployment', 'Data Center', 'Cloud WLC', 'Core Layer', 'Distribution Layer', 'Lightweight APs', 'Access Layer', 'beyond that, then additional WLCs can be added as more virtual machines.']
# 9
# ['Figure 27-8 WLC Location in a Unified Deployment', 'Unified WLC', 'Core Layer', 'Distribution Layer', 'Lightweight APs', 'Access Layer', '27', 'Technet24', 'security policies that affect all wireless users.']
# 28
# ['Figure 27-7 Using CAPWAP Tunnels to Connect APs to One Central WLC', 'CAPWAP', 'CAPWAP', 'CAPWAP', 'VLAN 100 VLAN 200', 'SSID 200', 'SSID 100', 'SSID 200', 'SSID 200 SSID 100', 'SSID 100', 'SSID 200', 'SSID 100', 'CAPWAP', 'Lightweight APs', 'WLC', 'Figure 27-6 Extent of VLAN 100 in a Cisco Wireless Network', 'VLAN 100 VLAN 200', 'SSID 100', 'CAPWAP', 'Access Link', 'Lightweight AP', 'WLC', 'SSID 200', '10.10.10.10', '10.1.1.5', '27', 'Technet24', 'reach every AP through the network of tunnels.']
# 6
# ['Figure 27-5 Linking a Lightweight AP and WLC with CAPWAP', 'CAPWAP Data – UDP 5247', 'Lightweight AP', 'CAPWAP Control – UDP 5246', 'WLC', 'Lightweight Access Point Protocol (LWAPP), which was a legacy Cisco proprietary solution.']
# 16
# ['Figure 27-4 Autonomous Versus Lightweight Access Point', 'CAPWAP', '• Encryption', '• MAC Management', '• RF Transmit/Receive', 'Real-Time Functions', '• QoS', '• Security Management', '• Client Authentication', '• Association and Roaming Management', '• RF Management', 'Management Functions', 'Lightweight AP', 'WLC', 'Autonomous AP', 'groups—management functions on the top and real-time processes on the bottom.']
# 17
# ['Figure 27-3 Cisco Meraki Cloud-Based Wireless Network Architecture', 'Cloud', 'Cisco Meraki', 'APs', 'Cisco Meraki', 'Access Layer', 'Layer', 'Distribution', 'Data', 'Trunk Link', 'Trunk Link', 'Core Layer Management', '27', 'Technet24', '1 A 2 B 3 C 4 B 5 A 6 C 7 A 8 D', 'Answers to the “Do I Know This Already?” quiz:', 'APs are managed, controlled, and monitored centrally from the cloud.']
# 26
# ['Figure 27-2 Extent of a Data VLAN in a Network of Autonomous APs', 'wlan200', 'wlan100', 'SSIDs:', 'wlan200', 'wlan100', 'SSIDs:', 'wlan200', 'wlan100', 'SSIDs:', 'wlan200', 'wlan100', 'SSIDs:', 'APs', 'Autonomous', 'Access Layer', 'Layer', 'Distribution', 'Management: 10.10.10.10', 'Trunk Link: VLANs 10, 100, 200', 'Trunk Link: VLANs 10, 100, 200', 'VLAN 200: 192.168.200.1/24', 'VLAN 100: 192.168.100.1/24', 'VLAN 10: 10.10.10.1/24', 'Core Layer', 'efficient.']
# 17
# ['Figure 27-1 Wireless Network Architecture with Autonomous APs', 'APs', 'Autonomous', 'Access Layer', 'Layer', 'Distribution', 'Core Layer', 'wlan200', 'wlan100', 'SSIDs:', 'Management: 10.10.10.10', 'Trunk Link: VLANs 10, 100, 200', 'Trunk Link: VLANs 10, 100, 200', 'VLAN 200: 192.168.200.1/24', 'VLAN 100: 192.168.100.1/24', 'VLAN 10: 10.10.10.1/24', 'network could consist of hundreds or thousands of APs.']
# 16
# ['Figure 26-22 Channel Layout in the 5-GHz Band', 'U-NII-1 U-NII-2 U-NII-2 Extended U-NII-3', 'GHz', '5.180 5.240 5.260 5.320 5.500 5.700 5.745 5.825', 'Channel', '36 40 44 48 52 56 60 64 100104 108 112 116 120 124 128 132 136 140 149 153 157 161', 'MHz', '20', 'Figure 26-21 Channel Layout in the 2.4-GHz Band', 'OFDM: 20 MHz', 'DSSS: 22 MHz', '2 3 4 5 7 8 9 10 12 13 14', 'GHz 2.467 2.472 2.484', 'Channel 1 6 11', '2.412 2.417 2.422 2.427 2.432 2.437 2.442 2.447 2.452 2.457 2.462', 'respectively.']
# 42
# ['Figure 26-20 Continuous Frequency Spectrum', '1012', 'Low Frequency Radio Radio Frequencies (RF)', '2.4 GHz Wireless', '5 GHz Wireless', 'Cosmic Rays', 'Gamma Rays', 'X-Rays', 'Ultraviolet Light', 'Visible Light', 'Infrared Light', 'Microwave and Radar', 'Television and FM Radio', 'Shortwave Radio', 'AM Radio', 'Sound', '0 0 Hz Subsonic', '101 10 Hz', '102 100 Hz', '103 1 kHz', '104 10 kHz', '105 100 kHz', '106 1 MHz', '107 10 MHz', '108 100 MHz', '109 1 GHz', '1010 10 GHz', '1011 100 GHz', '1013', '1014', '1015', '1016', '1017', '1018', '1019', '1020', '1021', 'Notation', 'Frequency', '(Hz)', 'Frequency', 'highest range of frequencies contains light, followed by X, gamma, and cosmic rays.']
# 6
# ['Figure 26-19 Cycles Within a Wave', '= 4 Hertz', 'Frequency = 4 cycles/second', '1 Second', 'Cycle Cycle', 'where it is ready to repeat the same cyclic pattern.']
# 4
# ['Figure 26-18 Wave Propagation with an Idealistic Antenna', 'Sender', 'Receiver', 'receiver, in addition to many other locations in other directions.']
# 4
# ['Figure 26-17 Traveling Electric and Magnetic Waves', 'Magnetic Field', 'Electric Field', 'fields cycling and pushing ever outward.']
# 3
# ['Figure 26-16 Sending a Continuous Wave Down a Rope', 'Sender Receiver', 'sender to the receiver.']
# 4
# ['Figure 26-15 Failed Attempt to Pass a Message Down a Rope', '?', 'Sender Receiver', 'and the receiver never notices a change.']
# 3
# ['Figure 26-14 Typical Wireless Mesh Network', 'LAN', 'the mesh APs.']
# 3
# ['Figure 26-13 Point-to-Multipoint Outdoor Bridge', 'LAN A Central LAN B', 'the point-to-multipoint scenario.']
# 3
# ['Figure 26-12 Point-to-Point Outdoor Bridge', 'LAN A Bridge Bridge LAN B', 'shown in Figure 26-12.']
# 7
# ['Figure 26-11 Nonwireless Device Connecting Through a Workgroup Bridge', 'Client B', 'WGB', 'Client A', 'AP', 'BSS', 'associated with the AP through a WGB.']
# 7
# ['Figure 26-10 Extending the Range of an AP with a Wireless Repeater', 'Repeater', 'Client B', 'Client A', 'AP', 'BSS', 'of both the AP and the distant client, as shown in Figure 26-10.']
# 15
# ['Figure 26-8 Scaling Wireless Coverage with an 802.11 Extended Service Set', 'ESS', 'SSID: “MyNetwork”', 'e6:22:47:af:c3:70', 'BSSID:', 'BSS-2', 'AP-2', 'VLAN 10', 'SSID: “MyNetwork”', 'd4:20:6d:90:ad:20', 'BSSID:', 'AP-1', 'BSS-1', 'Technet24', 'channel to channel.']
# 11
# ['Figure 26-7 Supporting Multiple SSIDs on One AP', 'SSID: “Guest”', 'SSID: “YourNetwork”', 'SSID: “MyNetwork”', 'BSSID: d4:20:6d:90:ad:23', 'BSSID: d4:20:6d:90:ad:22', 'VLANs 10, 20, 30', '802.1Q Trunk', 'BSSID: d4:20:6d:90:ad:21', 'DS', 'must contend for airtime on the same channel.']
# 9
# ['Figure 26-6 Distribution System Supporting a BSS', 'VLAN 10', 'SSID: “MyNetwork”', 'd4:20:6d:90:ad:20', 'BSSID:', 'DS', 'AP', 'BSS', '“MyNetwork” SSID will appear to be connected to VLAN 10.']
# 7
# ['Figure 26-5 Traffic Flows Within a BSS', 'd4:20:6d:90:ad:20', 'BSSID:', 'SSID: “MyNetwork”', 'AP', 'BSS', 'or recipient is the AP.']
# 3
# ['Figure 26-3 Interference from Simultaneous Transmissions', 'Device A Device B Device C Device D', 'all of them transmit at the same time.']
# 5
# ['Figure 26-2 Bidirectional Communication', 'Device A Device B', 'Receiver Transmitter', 'Transmitter Receiver', 'to take a turn to send at other times.']
# 4
# ['Figure 26-1 Unidirectional Communication', 'Device A Device B', 'Transmitter Receiver', 'sounds simple, except that it is not really practical.']
# 18
# ['Figure 25-11 Example Duplicate Address Detection (DAD) with NDP NS/NA', 'be a Duplicate!', 'Got NA—Must', 'NS for Myself', 'Do DAD: Send', '2001:DB8:1111:1::11 /64', 'MAC 0200:2222:2222', 'PC2', '2001:DB8:1111:1::11 /64', 'NA 3', 'I am MAC 0200:2222:2222', 'I am 2001:DB8:1111:1::11', '1 4', '2', 'PC1', 'NS', 'Reply if You Are 2001:DB8:1111:1::11', 'address exists.']
# 8
# ['Figure 25-10 Host IPv6 Address Formation Using SLAAC', '1 2', 'EUI-64 or Random', 'Chosen by Host', 'Interface ID', 'Learned from Router (NDP RA)', 'Prefix', '2 in the process, with the next topic detailing the third step (DAD).']
# 11
# ['Figure 25-9 Example NDP RS/RA Process to Find the Default Routers', '(Link-Local)', 'FE80::213:19FF:FE7B:5004', 'RA 2', 'I Am: FE80::213:19FF:FE7B:5004', '1', 'PC1', 'R1', 'RS', 'All Routers—Identify Yourselves', 'is indeed simple, with PC1 first asking and R1 replying.']
# 13
# ['Figure 25-8 Example NDP NS/NA Process to Find the Neighbor’s Link Addresses', '2001:DB8:1111:1::11 /64', 'MAC 0200:2222:2222', 'PC2', '2001:DB8:1111:1::22 /64', 'NA 2', 'I am MAC 0200:2222:2222', 'I am 2001:DB8:1111:1::22', '1', 'PC1', 'NS', 'Reply if You Are 2001:DB8:1111:1::22', 'the original host that asked the question, lists that link address.']
# 11
# ['Figure 25-7 Sample Topology for Incorrect IPv6 Route Examples', 'FE80::2', '2001:DB8:9:1::/64 2001:DB8:9:2::/64', 'R1 R2', '2001:DB8:9:3::/64', 'G0/2 G0/1 G0/2 B', '::2 ::2', '::9 G0/1 ::9', '::1 ::1', 'A', 'the subnet on the far right.']
# 16
# ['Figure 25-6 Using a Floating Static Route to Key Subnet 2001:DB8:1111:7::/64', '2001:DB8:1111:9::3', '2001:DB8:1111:7::/64', 'Subnet', 'EoMPLS', 'Backup Link (T1; Static)', 'Primary Link (OSPF)', 'Network', 'Enterprise', 'Core of the', 'S0/0/1', 'G0/0', 'R2', 'R1', 'R3', 'use the static route or the OSPF-learned route.']
# 19
# ['Figure 25-5 Using Static Default Routes at Branches to Forward Back to the Core', 'B2', 'Core', 'G0/0/0', 'G0/1/0', 'Offices', 'Branch', 'Default Route (::/0)', 'Default Route (::/0)', 'S0/0/1', 'S0/0/0', ':3', ':2', ':1', ':1', 'B1', 'G0/0', ':1', 'with two sample branch routers on the right and a core site router on the left.']
# 22
# ['Figure 25-4 Network Details for IPv6 Static Routes on an Ethernet Interface', 'R1 R3', 'A', '2001:DB8:1111:1:: /64', 'Subnet 1', 'B For Packets Destined to this Subnet', '2001:DB8:1111:5::1 G0/0/0', 'A', 'B', 'G0/1/0 C', '2001:DB8:1111:3:: /64', 'Subnet 2', ':3', 'G0/0', ':33', 'G0/0', ':11 :1', 'A 2001:DB8:1111:5::3', 'For Packets Destined to this Subnet', 'Send to Neighbor Unicast and Out G0/0/0', 'Send to Global Unicast', 'to the LAN subnet on the left of the figure, labeled with a “B.”.']
# 20
# ['Figure 25-3 Using Unicast or Link-Local as the Next-Hop Address for Static Routes', 'FE80::FF:FE00:1', '2001:DB8:1111:4::1 B', 'R1', '2001:DB8:1111:1:: /64', 'Subnet 1', '2001:DB8:1111:2:: /64', 'Subnet 2', ':2', 'G0/0', ':22', 'G0/0', ':11 :1', 'A', 'FE80::FF:FE00:2 R2', '2001:DB8:1111:4::2', 'For Packets Destined to this Subnet', 'Send to Link-Local', 'Send to Global Unicast', 'this time showing Router R2’s global unicast as well as R2’s link-local address.']
# 22
# ['Figure 25-2 Logic Behind IPv6 Static Route Commands (IPv6 Route)', 'S0/0/1', 'B', 'R1', '2001:DB8:1111:4:: /64', 'Subnet 4', '2001:DB8:1111:1:: /64', 'Subnet 1', '2001:DB8:1111:2:: /64', 'Subnet 2', ':2', 'G0/0', ':22', 'G0/0', ':11 :1', 'A', 'R2', 'S0/0/0 2001:DB8:1111:4::2', 'For Packets Destined to this Subnet', 'Send out Here or… Send to There', 'Technet24', 'next-hop link-local address. This section ends with a discussion of static IPv6 default routes.']
# 28
# ['Figure 25-1 Sample Network Used to Show Connected and Local Routes', 'R3', 'R1', 'G0/0/0', 'G0/1/0', '2001:DB8:1111:3:: /64', 'Subnet 3', '2001:DB8:1111:4:: /64', 'Subnet 4', '2001:DB8:1111:5:: /64', 'Subnet 5', '2001:DB8:1111:2:: /64', 'Subnet 2', 'S0/0/1', 'S0/0/0', '::3', '::2', '::1', '::1', 'R2', '::3 :33 G0/0 C', '2001:DB8:1111:1:: /64', 'Subnet 1', '::2 :22 G0/0 B', '::11 G0/0', '::1', 'A', 'upcoming examples focus on the connected and local routes on Router R1.']
# 13
# ['Figure 24-13 IPv6 Anycast Addresses', 'R8', 'R2', 'R6 R7', '1', '2', 'R5', 'R1', 'R3 R4', '2', 'Identical Anycast Address Configured on Both Routers', 'Technet24', 'address.']
# 7
# ['Figure 24-12 Solicited-Node Multicast Address Format', 'of Unicast Address', 'Last 6 Hex Digits', 'Abbreviation: FF02::1:FF_ _ : _ _ _ _', 'Defined by RFC', 'FF02 : 0000 : 0000 : 0000 : 0000 : 0001 : FF _ _ : _ _ _ _', 'into the solicited-node address.']
# 11
# ['Figure 24-11 IPv6 Multicast Scopes', '2', '1', 'Internet', 'R3 R4', 'R2', 'R1', 'Organization-local', 'Site-local', 'Link-local', 'the organization over the link to the Internet.']
# 9
# ['Figure 24-10 Typical Use of the ipv6 enable Command', 'R1 R2', 'ipv6 enable ipv6 enable', '2001:DB8:1111:1::/64 2001:DB8:1111:2::/64', 'Global Unicast Prefix', 'Link Locals Only!', 'Global Unicast Prefix', 'PC1 PC2', 'WAN interface addresses.']
# 6
# ['Figure 24-9 Link-Local Address Format', '64 Bits', 'Interface ID: EUI-64', '64 Bits', 'FE80 : 0000 : 0000 : 0000', 'with FE80:0000:0000:0000 as the first four unabbreviated quartets.']
# 11
# ['Figure 24-8 IPv6 Using Link-Local Addresses as the Next-Hop Address', 'R1 R2', 'R2 Link Local', 'Next-Hop', '1 2', '2001:DB8:1111:2::/64', 'Gw=R1 Link Local Subnet 2', 'PC1 PC2', 'Subnet 2', 'Prefix', 'rather than the global unicast or unique local unicast address.']
# 41
# ['Figure 24-7 A Mnemonic Device to Help Memorize Bit Inversion Shortcut', 'Space', 'Little', 'A', 'A Little Space', 'F', 'D', 'B', '9', '7', '5', '3', '1', 'E', 'C', 'A', '8', '6', '4', '2', '0', 'Step 2:', 'F', 'D', 'B', '9', '7', '5', '3', '1', 'E', 'C', 'A', '8', '6', '4', '2', '0', 'Step 1:', 'Technet24', 'on the right, re-creating the right side of Figure 24-7.']
# 23
# ['Figure 24-6 Inverting the Seventh Bit of an EUI-64 Interface ID Field', '4', '3', '2', '1', '14', '0001 0100', '0001 0110', '16', 'Hex', 'Binary', 'Binary', 'Hex', 'Convert to Hex', 'Invert 7th Bit', 'Convert to Binary', 'First 2 Hex Digits', '02', '0000 0010', '0000 0000', '00', 'Example 1 Example 2', 'to 0. Finally, the bits are converted back to hex at Step 4.']
# 24
# ['Figure 24-5 Two Examples of Most of the EUI-64 Interface ID Process', '(1 Step Left)', '4', '3', '2', '1', '1612:34 56:789A', '161234 56789A', '161234 56789A', 'FF:FE', 'FFFE', '1612.3456.789A', 'Example 1 Process Example 2', 'Interface ID', 'Insert FFFE', 'Halves', 'MAC', '0013:12 34:ABCD', '001312 34ABCD', '001312 34ABCD', 'FF:FE', 'FFFE', '0013.1234.ABCD', 'the process.']
# 10
# ['Figure 24-4 IPv6 Address Format with Interface ID and EUI-64', 'Calculated by Router Using EUI-64', '(Reading Left to Right)', 'Invert 7th Bit, 1st Byte', 'Defined by Configuration', 'of MAC', 'of MAC FFFE 2nd Half', '1st Half', 'Subnet Prefix', 'Figure 24-4 shows the major pieces of how the address is formed.']
# 13
# ['Figure 24-3 Sample 128-bit IPv6 Addresses to Be Configured on Cisco Router Interfaces', 'R1 G0/0/0 G0/1/0 R2', '2001:DB8:1111:2::/64', 'Subnet', '2001:DB8:1111:1::/64', 'Subnet', '2001:DB8:1111:4::/64', 'Subnet', '2001:DB8:1111:2::2', '2001:DB8:1111:4::2', '2001:DB8:1111:1::1 2001:DB8:1111:4::1', 'G0/0 G0/0', 'use a /64 prefix length.']
# 14
# ['Figure 24-2 Possible Path Through Dual-Stack (IPv4 and IPv6) over a Long Period', 'IPv6', 'TCP/IP IPv6', 'TCP/IP', 'IPv4', 'TCP/IP IPv4', 'TCP/IP', 'IPv6', 'TCP/IP', '2010s 2020s ??? 2030s ???', 'Technet24', '1 A 2 B 3 A, C 4 A 5 B', 'Answers to the “Do I Know This Already?” quiz:', 'addresses on routers.']
# 11
# ['Figure 24-1 Migration of Enterprise Networks to Use TCP/IP Stack Only, IPv4', 'Vendor IPv4', 'Other TCP/IP', 'IBM DEC', 'Vendor', 'Other', 'IBM DEC', 'IPv4', 'TCP/IP', '1980s 1990s 2000s', 'the only protocol stack in use.']
# 16
# ['Figure 23-12 Subnetting Using Unique Local Addresses', 'FD00:1:1:0003::/64', 'Prefix', 'Company 1 – Unique Local Prefix FD00:1:1::/48', 'FD00:1:1:0002::/64', 'Prefix', 'FD00:1:1:0004::/64', 'Prefix', 'FD00:1:1:0001::/64', 'Prefix', 'R1 R2', 'G0/0/0', 'G0/1/0', 'G0/0 G0/0/0 G0/1/0 G0/0', 'ISP', 'of FD00:1:1.']
# 8
# ['Figure 23-11 IPv6 Unique Local Unicast Address Format', '8 Bits', 'FD', '40 Bits 16 Bits 64 Bits', 'Subnet Interface ID', 'Subnet ID', 'Global ID (Pseudo-Random)', 'Figure 23-11 shows the format of these unique local unicast addresses.']
# 16
# ['Figure 23-10 Example Static IPv6 Addresses Based on the Subnet Design of Figure 23-9', 'R1 G0/0/0 G0/1/0 R2', 'G0/0/0', 'ISP', '2001:DB8:1111:3::9', '2001:DB8:1111:3::2', '2001:DB8:1111:2::2', '2001:DB8:1111:2::1', '2001:DB8:1111:1::1', '2001:DB8:1111:1::9', 'G0/0 G0/0', '2001:DB8:1111:4::3', '2001:DB8:1111:4::1', 'PC1 PC2', 'G0/1/0', 'interfaces use an interface ID that is a relatively low number, easily remembered.']
# 15
# ['Figure 23-9 Subnets in Company 1, with Global Routing Prefix of 2001:0DB8:1111::/48', 'R1 G0/0/0 G0/1/0 R2', '2001:DB8:1111:0002::/64', 'Prefix', '2001:DB8:1111:0003::/64', 'Prefix', '2001:DB8:1111:0004::/64', 'Prefix', '2001:DB8:1111:0001::/64', 'Prefix', 'G0/0/0', 'G0/1/0', 'G0/0 G0/0', 'ISP', 'use those four subnets in other locations.']
# 36
# ['Figure 23-8 First 16 Possible Subnets with a 16-bit Subnet Field in This Example', '::', '::', '::', '::', '::', '::', '::', '::', '::', '::', '::', '::', '::', '::', '::', '::', 'Global Routing Prefix Subnet', '2001:0DB8:1111:000F', '2001:0DB8:1111:000E', '2001:0DB8:1111:000D', '2001:0DB8:1111:000C', '2001:0DB8:1111:000B', '2001:0DB8:1111:000A', '2001:0DB8:1111:0009', '2001:0DB8:1111:0008', 'Global Routing Prefix Subnet', '2001:0DB8:1111:0007', '2001:0DB8:1111:0006', '2001:0DB8:1111:0005', '2001:0DB8:1111:0004', '2001:0DB8:1111:0003', '2001:0DB8:1111:0002', '2001:0DB8:1111:0001', '2001:0DB8:1111:0000', 'Figure 23-8 shows the beginning of just such a list.']
# 7
# ['Figure 23-7 Address Structure for Company 1 Example', 'Subnet ID', 'Prefix ID', 'Global Routing Prefix Subnet Host', '48 Bits 16 Bits 64 Bits', '2001:0DB8:1111 0001 0000:0000:0000:0001', '###### The company has a subnet field of 16 bits, allowing for 216 IPv6 subnets.']
# 9
# ['Figure 23-6 Structure of Subnetted IPv6 Global Unicast Addresses', 'P + S + I = 128', 'RIR, or ISP', 'Set By IANA,', 'Engineer', 'Set by Local', 'P Bits S Bits I Bits', 'Global Routing Prefix Subnet Interface ID', 'a way to number and identify subnets, much like the subnet field in IPv4 addresses.']
# 10
# ['Figure 23-5 Classful View of Subnetted IPv4 Networks', 'Class B Rules', 'Set By', 'Engineer', 'Set by Local', 'B', 'N + S + H = 32', 'B N=16 S=__ H=__', 'Technet24', 'mask. Figure 23-5 shows the idea for a subnetted Class B network.']
# 8
# ['Figure 23-4 Classful View of Unsubnetted IPv4 Networks', 'C', 'B', 'A', 'N=24 H=8', 'N=16 H=16', 'N=8 H=24', 'the rest of the 32-bit IPv4 address, as shown in Figure 23-4.']
# 10
# ['Figure 23-3 Locations for IPv6 Subnets', 'R1 R2', 'Subnet 2 Subnet 3', 'Subnet 4', 'Subnet 1', 'G0/0/0', 'G0/1/0', 'G0/0 G0/0/0 G0/1/0 G0/0', 'ISP', 'Company 1 needs four IPv6 subnets.']
# 22
# ['Figure 23-2 Prefix Assignment with IANA, RIRs, and ISPs', '2001:0DB8:3333', '2001:0DB8:2222', '2001:0DB8:1111', '2001:BBBB', '2001:0DB8', '2ABC:…', '2001:…', 'IANA', '3', '2', '1', 'Company 3', 'Company 2', 'Company 1', '(Africa)', 'AfriNIC', 'NA-ISP2', '(North America)', 'ARIN', 'NA-ISP1', 'happened.']
# 21
# ['Figure 23-1 Three Global Routing Prefixes, with One Route per Prefix', 'R3', 'R2', 'R1', 'R4', 'R3', 'R2', 'R1', 'Next-Router', '2001:DB8:3333::/48', '2001:DB8:2222::/48', '2001:DB8:1111::/48', 'Destination', '2001:DB8:1111::/48', 'Company 1—', '2001:DB8:3333::/48', 'Company 3—', '2001:DB8:2222::/48', 'Company 2—', 'The Internet', 'prefix.']
# 14
# ['Figure 22-7 Creating the IPv6 Prefix from an Address/Length', 'Legend:', 'ID', 'ID', '2 3', '1 PPPP PPPP HHHH HHHH HHHH HHHH', '/64 PPPP PPPP', 'Prefix: Copy Host: Set to 0', '2001:0DB8:AAAA:0002:0000:0000:0000:0000', '2001:0DB8:AAAA:0002:1234:5678:9ABC:EF01', 'Subnet ID', '16 Digits', '64 Bits', 'digits of the IPv6 address, while Step 3 records hex 0s for the rest of the digits.']
# 15
# ['Figure 22-6 Comparing an IPv6 Packet to R1’s IPv6 Routing Table', 'Subnet 2345:1:2:3::/64', 'PC1 PC2', 'R1 R2', '•', '•', '2345:1:2:3::/64 S0/0/0 R2', 'R1 IPv6 Routing Table', 'IPv6 Prefix Output Interface Next-Router', 'S0/0/0', 'IPv6 Address', 'Destination', 'IPv6 Packet', 'Technet24', 'in the matched IPv6 route to forward the IPv6 packet. Figure 22-6 shows the overall process.']
# 14
# ['Figure 22-5 IPv6 Router Performing Routine Encapsulation Tasks When Routing IPv6', 'Subnet 2345:1:2:3::/64', '1 2', '1 2', 'PC2', 'IPv6 Packet', 'De-encapsulate', 'IPv6 Packet', 'Re-encapsulate', 'PC1', 'R1 R2', 'IPv6 Packet', 'Eth. IPv6 Packet Eth. HDLC IPv6 Packet HDLC', 'trailer to the IPv6 packet, encapsulating the IPv6 packet.']
# 8
# ['Figure 22-4 IPv6 Host Building and Sending an IPv6 Packet', 'Subnet 2345:1:2:3::/64', 'PC2', '– Send to Default Gateway', '– Encapsulate IPv6 Packet', 'PC1', 'R1 R2', 'IPv6 Packet Eth.']
# 12
# ['Figure 22-3 IPv6 Header', '(16 Bytes)', 'Destination Address', 'Payload Length', 'Class', 'Next Header Hop Limit', 'Version Flow Label', '4 Bytes', 'Bytes', '(16 Bytes) 40', 'Source Address', 'header.']
# 26
# ['Figure 22-2 Timeline for IPv4 Address Exhaustion and Short-/Long-Term Solutions', '1980 1990 2000 2010 2015', 'for IPv6', 'Defer Need', 'NAT, CIDR,', 'NAT, CIDR', 'Short Term:', 'RFCs', 'IPv6', '791', 'RFC', 'IPv4', 'Exhaustion', 'Address', 'of IPv4', 'Concerns', 'Final IPv4 Block', 'ARIN Allocates', 'IPv4', 'Replaces', 'IPv6', 'Final /8 Block', 'Allocates', 'IANA', '???', 'used in some documents, the next effort to update IP was numbered as version 6.']
# 16
# ['Figure 22-1 Some Major Events in the Growth of the Internet', 'Internet', 'Mobile', 'Pervasive', 'Internet', 'Fixed', 'Pervasive', '1970 1980 1990 2000 2010', '(.com)', 'Commerce', 'Research', 'Universities,', 'Begins', 'ARPANET', '2020', 'smaller address blocks to companies or ISPs.']
# 11
# ['Figure 21-5 Example Network to Demonstrate OSPF Process Shutdown', 'G0/2', 'G0/1', 'RID 3.3.3.3', 'R3', 'R2', 'R5', '10.1.13.1', '10.1.12.1', 'RID 2.2.2.2', 'show ip ospf neighbor and show ip ospf interface brief.']
# 22
# ['Figure 21-4 Summary of Problems That Prevent OSPF Neighbors on the Central LAN', '10.1.22.2/24', 'G0/1 G0/0', 'R4', 'R3 10.1.33.3/24', '10.1.1.3/24', '10.1.1.4/24 10.1.44.4/24', 'G0/0 G0/1', 'G0/0', 'G0/1', 'Hello/Dead = 5/20', 'Intended Design: Area 0 Only', '(Should be 3.3.3.3)', 'RID 1.1.1.1', 'Incorrect Configuration: Area 1', 'RID 1.1.1.1', 'R2', 'R1', '10.1.1.2/24', '10.1.11.1/24 10.1.1.1/24', 'G0/1 G0/0', 'Figure 21-4 shows these same problems for reference.']
# 21
# ['Figure 21-3 Sample OSPF Design with Serial and Ethernet WAN', 'S0/0/0 S0/0/1', 'R1 10.1.13.1 /24 10.1.13.3 /24', '10.1.12.1 /24', '10.1.14.1 /24', '10.1.1.1 /24 10.1.23.3 /24', 'G0/0', 'R4', 'R2', 'R3', 'Area 0', 'G0/1', 'G0/0', 'G0/0', '10.1.4.4 /24', '10.1.23.2 /24', '10.1.12.2 /24', 'G0/1/0 G0/0/0', 'G0/1/0 G0/0/0', '10.1.14.4 /24', 'Ethernet WAN links and one serial link.']
# 22
# ['Figure 21-2 OSPF DR/BDR/DROther Roles in the Network', 'RID 2.2.2.2 RID 4.4.4.4', 'RID 1.1.1.1 RID 3.3.3.3', 'DR', 'DR', 'DR', 'DR', 'DROther', 'DROther BDR', 'DR', 'R4', 'R3', 'R2', 'R1', 'G0/1 G0/1', 'G0/1 G0/0', 'G0/0 G0/0', 'G0/0 G0/1', 'Technet24', '1 B, D 2 B, C 3 D 4 A, D 5 C 6 D', 'Answers to the “Do I Know This Already?” quiz:', 'the DR or BDR fails—their neighbor relationship remains in a 2-way state.']
# 15
# ['Figure 21-1 The Single Area Design Used in This Chapter', 'RID 2.2.2.2 RID 4.4.4.4', 'RID 1.1.1.1 RID 3.3.3.3', 'R4', 'R3', 'R2', 'R1 10.1.1.3/24 10.1.33.3/24', '10.1.22.2/24 10.1.1.2/24', '10.1.11.1/24 10.1.1.1/24', '10.1.1.4/24 10.1.44.4/24', 'G0/1 G0/1', 'G0/1 G0/0', 'G0/0 G0/0', 'G0/0 G0/1', 'area 0, making the design a single area design.']
# 15
# ['Figure 20-7 Default Routes Resulting from the default-information originate Command', 'G0/0/0', 'G0/1/0', 'G0/3/0 192.0.2.1', '10.1.13.1', '10.1.12.1', 'R1', 'B1', 'B2', 'ISP1', 'Default', 'Default', 'Default', 'Internet', 'own default route fails.']
# 20
# ['Figure 20-6 Using OSPF to Create and Flood a Default Route', 'default-information originate', 'default-information originate', 'R1', 'B1', 'B2', 'ISP1', 'G0/0/0 ip route 0.0.0.0 0.0.0.0 192.0.2.1', 'G0/1/0', 'G0/0/0', 'G0/1/0', 'G0/3/0', '192.0.2.1', 'OSPFv2 Advertises Default', 'OSPFv2 Advertises Default', 'Internet', '2', '2', '1', 'makes the router advertise a default route using OSPF to the remote routers (B1 and B2).']
# 27
# ['Figure 20-5 Area Design Used in the Upcoming OSPF Interface Config Example', 'R1 10.1.13.1 /24 10.1.13.3 /24', '10.1.12.1 /24', '10.1.14.1 /24', '10.1.23.3 /24', '10.1.2.1 /24', '10.1.1.1 /24', 'G0/0.2', 'G0/0.1', 'R4', 'R2', 'R3', 'Area 0', 'G0/1', 'G0/0', 'G0/0', '10.1.4.4 /24', '10.1.23.2 /24', '10.1.12.2 /24', 'G0/0/0', 'G0/2/0 G0/0/0', 'G0/1/0', 'G0/1/0 G0/0/0', '10.1.14.4 /24', 'Checklist', 'Config', 'upcoming interface configuration example.']
# 26
# ['Figure 20-4 Area Design for an Example Multiarea OSPF Configuration', 'R1 10.1.13.1 /24 10.1.13.3 /24', '10.1.12.1 /24', '10.1.14.1 /24', '10.1.23.3 /24', '10.1.2.1 /24', '10.1.1.1 /24', 'G0/0.2', 'G0/0.1', 'R4', 'R2', 'R3', 'G0/1', 'G0/0', 'G0/0', '10.1.4.4 /24', '10.1.12.2 /24 10.1.23.2 /24', 'G0/0/0', 'G0/2/0 G0/0/0', 'G0/1/0', 'G0/1/0 G0/0/0', '10.1.14.4 /24', 'Area 23', 'Area 0', 'Area 4', 'design shown in Figure 20-2.']
# 29
# ['Figure 20-3 OSPF Verification Commands', 'show ip route | section subnet', 'show ip route subnet mask', 'show ip route ospf', 'show ip route', 'Routes', 'Admin Distance', 'show ip ospf rib', 'show ip ospf database', 'show ip ospf neighbor type number', 'show ip ospf neighbor', 'show ip ospf interface brief', 'show ip ospf interface type number', 'show ip ospf interface', 'show ip protocols', 'show running-config', 'Neighbors', 'LSDB', 'RIB', 'Interfaces', 'Enabled', 'Config', 'SPF Calculation', 'Flood LSAs', 'with Hello', 'Discover', 'ip ospf Commands', 'network and', 'shows all three.']
# 25
# ['Figure 20-2 Sample Network for OSPF Single-Area Configuration', 'R1 10.1.13.1 /24 10.1.13.3 /24', '10.1.12.1 /24', '10.1.14.1 /24', '10.1.23.3 /24', '10.1.2.1 /24', '10.1.1.1 /24', 'G0/0.2', 'G0/0.1', 'R4', 'R2', 'R3', 'Area 0', 'G0/1', 'G0/0', 'G0/0', '10.1.4.4 /24', '10.1.23.2 /24', '10.1.12.2 /24', 'G0/0/0', 'G0/2/0 G0/0/0', 'G0/1/0', 'G0/1/0 G0/0/0', '10.1.14.4 /24', 'three-digit, or both.']
# 14
# ['Figure 20-1 Organization of OSPFv2 Configuration with the network Command', 'Interface Mode: Indirect!', 'ip address 10.1.1.1 255.255.255.0', 'interface S0/0/0', 'network 10.0.0.0 0.255.255.255 area 0', 'Define Area Number', 'router-id 1.1.1.1 Set Router ID (Optional)', 'Configuration', 'router ospf 1', 'OSPF Mode:', 'Define Process ID', 'on the Interface', '(Indirectly) Enable OSPF Process', 'discusses more about this logic.']
# 24
# ['Figure 19-17 Type 1 and Type 2 LSAs in Area 0, Assuming a Single-Area Design', '1', 'Type', 'R4', '1', 'Type', 'R1', '2', 'Type', '4.4.4.4', '2', 'Type', '1', 'Type', 'R2', '2.2.2.2', '3.3.3.3', '1', 'Type', 'R3', '1.1.1.1', '2', 'Type', 'SPF processes connect the pieces together.']
# 18
# ['Figure 19-16 Type 1 LSAs, Assuming a Single-Area Design', '1', 'Type', 'R2', '4.4.4.4', '2.2.2.2', '3.3.3.3', '1', 'Type', 'R4', '1', 'Type', 'R3', '1.1.1.1', '1', 'Type', 'R1', 'figure out which interfaces connect to which other routers.']
# 18
# ['Figure 19-15 Enterprise Network with Seven IPv4 Subnets', 'R2', 'R4', 'R1 R3', 'Area 0', '10.1.13.0/24', 'G0/1', 'G0/0', 'G0/0', '10.1.4.0/24', '10.1.1.0/24 10.1.12.0/24 10.1.23.0/24', 'G0/0/0', 'S0/0/0 S0/0/1', 'G0/1/0', 'G0/1/0 G0/0/0', 'G0/0', '10.1.14.0/24', 'The LSA lists that router’s own interfaces, IP address/mask, with pointers to neighbors.']
# 15
# ['Figure 19-14 Smaller Area 1 LSDB Concept', 'ABR', 'Area 1 LSDB', 'Requires Little SPF', 'Subnets in Other Areas:', '10.1.11.0', '10.1.12.0', '10.1.13.0', 'Requires Heavy SPF', 'Detailed Topology Data (Routers and Links):', '10.1.14.0', 'B3 B4', 'D1', 'B1 B2', 'Figure 19-14.']
# 17
# ['Figure 19-13 Three-Area OSPF with D1 and D2 as ABRs', 'SW1 SW2', '10.1.11.0 10.1.12.0 10.1.13.0 10.1.14.0', 'Internal Routers', 'Area 1 Area 2', 'Area 0 (Backbone)', 'Router Area Border Router (ABR)', 'Backbone', 'Internal Routers', 'D3', 'B13 B14', 'D2', 'B3 B4 B11 B12', 'D1', 'B1 B2', 'Technet24', 'from the figure.']
# 12
# ['Figure 19-12 Single-Area OSPF', 'Area 0 (Backbone)', 'D3', 'B13 B14', 'D2', 'B11 B12', 'SW2', 'B3 B4', 'D1', 'B1 B2', 'SW1', 'Figure 19-12 shows one such network example, with 11 routers and all interfaces in area 0.']
# 4
# ['Route Location in Figure 19-11 Cumulative Cost', 'Table 19-6 Comparing R1’s Three Alternatives for the Route to 172.16.3.0/24', 'Technet24', 'that R1’s best route to 172.16.3.0/24 starts by going through R5.']
# 21
# ['Figure 19-11 SPF Tree to Find R1’s Route to 172.16.3.0/24', 'Legend:', 'R8', 'R6', 'R5', 'R4', 'R7 R3', 'R2', 'R1', 'Possible Route', 'Cost 40', '(172.16.3.0/24)', 'Subnet X', 'Cost 10', 'Cost 5', 'Cost 180 Cost 20', 'Cost 60', 'Cost 10 Cost 30', 'Cost 30', 'Cost 20', '(172.16.3.0/24) at the bottom of the figure.']
# 6
# ['Figure 19-10 Database Exchange to and from the DR on an Ethernet', 'Database Exchange Flows', 'A', 'B C D E', 'Designated Router', 'words, the database exchange happens over the flows shown in Figure 19-10.']
# 4
# ['Figure 19-9 Routers A and B Elected as DR and BDR', 'B D BDR', 'DR A C E', 'BDR, for no other reason than the Ethernet must have one of each.']
# 3
# ['Figure 19-8 Database Exchange Example, Ending in a Full State', 'R1 R2', '...']
# 15
# ['Figure 19-7 Early Neighbor States', 'R1 R2', '4', '3', '2', '1', '2-Way', '2-Way', 'Init', '(R1 to R2 Link comes up…)', 'Hello, Seen [1.1.1.1, 2.2.2.2], My RID 1.1.1.1', 'Hello, Seen [1.1.1.1], My RID 2.2.2.2', 'RID 1.1.1.1 RID 2.2.2.2', 'Hello, Seen [null], My RID 1.1.1.1', 'an OSPF state variable for how it views the neighbor.']
# 11
# ['Figure 19-6 OSPF Hello Packets', 'R1 R2', 'Hello', 'Hello', 'Interval', 'Hello', 'Hello', 'Hello', 'Interval', 'Hello', 'routers connected to those interfaces. Figure 19-6 outlines the basic concept.']
# 32
# ['Figure 19-5 Flooding LSAs Using a Link-State Routing Protocol', 'R6 R8', 'R4', 'R7', 'R2 R3', 'R1 R5', 'Cost: 10', 'State: UP', 'Int. IP Address: 172.16.3.1/24', 'Router ID: 8.8.8.8', 'R8 Router LSA – Partial Contents', 'R8 LSA R8 LSA', 'R8 LSA R8 LSA', 'R8 LSA R8 LSA', 'R8 LSA R8 LSA R8 LSA', 'Cost 10', '172.16.3.1/24', '172.16.3.0/24', 'Fa0/0', 'shows only a subset of the information in R8’s router LSA.)', 'of subnet 172.16.3.0/24, as seen on the right side of the figure. (Note that Figure 19-5 actually', 'router LSA. The router LSA for Router R8 describes the router itself, including the existence', 'Figure 19-5 shows the general idea of the flooding process, with R8 creating and flooding its', 'Figure 19-4 LSA and LSDB Relationship', 'Link State Database (LSDB)', 'LSA', 'LSA', 'LSA', 'LSA', 'LSA', 'LSA', 'topology; the LSDB is simply the collection of all the LSAs known to a router.']
# 23
# ['Figure 19-3 RIP and OSPF Metrics Compared', 'C', 'A B', 'C', 'A B', '1,000,000', '1,000,000 Bandwidth', 'Bandwidth', 'Bandwidth 1544', 'OSPF', 'Subnet 10.1.1.0', 'S0/0/1', 'G0/0', '1,000,000', 'Bandwidth', '1,000,000', 'Bandwidth', 'Bandwidth 1544', 'RIP', 'S0/0/1', 'G0/0', 'Subnet 10.1.1.0', 'Ethernet WAN links.']
# 26
# ['Figure 19-2 Comparing Locations for Using IGPs and EGPs', 'EIGRP', 'ISP4', 'BGP', 'BGP', 'BGP', 'BGP', 'ASN 300', 'ASN 400', 'ASN 200', 'EIGRP', 'ISP2', 'OSPF', 'ISP3', 'ASN 500', 'OSPF', '199.190.1.0', 'Subnets of Network', 'Enterprise 5', 'ASN 100', 'BGP', 'EIGRP', '9.0.0.0', 'Subnets of Network', 'Enterprise 1', 'used between the ASNs.']
# 8
# ['Figure 19-1 Three of the Four Basic Functions of Routing Protocols', '3 2', '1', '1', 'R3', 'R1 R2', '172.16.1.0/24 172.16.3.0/24', 'has the lower metric.']
# 5
# ['Figure 18-15 Successive Telnet Connections: PC1 to R1, R1 to R2, and R2 to R3', 'PC1 .1 .1 .2 .2 .3', 'R1> telnet 10.1.2.2 R2> telnet 10.1.3.3', 'R1 Subnet 10.1.2.0/24 R2 Subnet 10.1.3.0/24 R3', 'which the user could issue commands on R3.']
# 14
# ['Figure 18-14 Telnet Works from PC1 to R1 but Not to R2 or R3', 'PC1', 'G0/1', '.2', 'G0/2', '.3', 'G0/2', '.2', 'G0/1 G0/1', '10.1.1.0/24 10.1.2.0/24 10.1.3.0/24', 'G0/2', '.1 .1', 'R1 R2 R3', '(R3) fails.']
# 12
# ['Figure 18-13 TTL=2 Message Sent by traceroute', 'R1 R2', 'G0/0/1', '4', 'Source 172.16.4.2', 'TTL Exceeded', '1 2 IP TTL=1 3', 'TTL – 1 = 0', 'IP TTL=2', '172.16.4.2 172.16.2.101', 'A 172.16.1.1 B', 'TTL Exceeded message to be sent back to host A.']
# 12
# ['Figure 18-12 How traceroute Identifies the First Router in the Route', '3', 'Source 172.16.1.1', 'TTL Exceeded', '2', '1', 'TTL – 1 = 0', 'IP TTL=1', 'A', 'R1', '172.16.1.1', 'Exceeded message, which identifies the router’s IP address to the traceroute command.']
# 8
# ['Figure 18-11 IP Addresses Identified by a Successful traceroute 172.16.2.101 Command', 'R1 R2', '172.16.4.2 172.16.2.101', 'A', 'traceroute 172.16.2.101', '172.16.1.1', 'B', 'the figure. Example 18-4, which follows, lists the output of the command, taken from host A.']
# 10
# ['Figure 18-10 DNS Name Resolution by Host A', '2', '1', 'R3', 'R2', 'B', 'R1', 'A', 'DNS', '172.16.2.101, host B’s IP address (Step 2).']
# 11
# ['Figure 18-9 Pinging Across a WAN Link', 'R1 R2', 'B', '.51 172.16.2.101', 'SW1 SW2', 'A', 'ping 172.16.4.2', 'Echo Reply', 'Echo Request', '172.16.4.1 172.16.4.2', '172.16.4.2 command on R1 in Figure 18-9.']
# 16
# ['Figure 18-8 Extended ping Command Does Test Host A’s Default Router Setting', 'R1 R2', '2', '3', '1', 'Echo Reply', 'Echo Request', 'Another Subnet!', 'Destination 172.16.4.1…', '172.16.4.0 /24', '172.16.1.0 /24', 'A', 'ping 172.16.1.51', '.51 172.16.1.1 172.16.4.1', 'Technet24', 'with the host’s default router setting.']
# 12
# ['Figure 18-7 Standard ping Command Confirms That the LAN Works', 'R1 R2', 'Same Subnet!', 'Destination 172.16.1.1…', '.51', 'Echo Reply', 'Echo Request', 'A', 'ping 172.16.1.51', '172.16.1.0 /24', '.1', 'issues the command ping 172.16.1.51, pinging host A, which sits on the same VLAN as R1.']
# 13
# ['Figure 18-6 Extended Ping Command Tests the Route to 172.16.1.51 (Host A)', 'R1 R2', '.51', 'A G0/0 B', 'SW1 SW2', '.101', '.2', 'G0/0/0', 'Echo Reply', 'Echo Request', '172.16.1.1', '172.16.1.0/24 172.16.2.0/24', 'shown in Figure 18-6.']
# 23
# ['Figure 18-5 Router and Host ARP Tables, with the Switch MAC Address Table', '172.16.2.2 172.16.2.101', 'B', 'R2', 'Host B ARP Table', 'IP Address', '172.16.2.2 0200.0202.0202', 'MAC Address', 'R2 ARP Table', 'IP Address', '172.16.2.101 0200.2222.2222', 'MAC Address', 'F0/10', '0200.0202.0202 0200.2222.2222', 'SW2 Address Table', 'Output', '0200.0202.0202', '0200.2222.2222', 'F0/10', 'F0/2', 'MAC Address', 'F0/2', 'information expected in those tables.']
# 13
# ['Figure 18-4 Locations Where IP ACLs Could Have Filtered the Ping Messages', 'R1 R2', 'Out', '172.16.2.101', 'B', '.51', 'SW1 SW2', 'A', 'In', 'In', 'In Out', 'Technet24', 'packets created on R1, so there is no rightward-facing arrow over R1.).']
# 14
# ['Figure 18-3 Layer 3 Routes Needed for R1’s Ping 172.16.2.101 to Work', 'R1 R2', '172.16.2.101', 'B', '.51', 'SW1 .2 SW2', 'A', '172.16.4.1', 'Default Router', 'Static or Dynamic', 'Connected', 'Connected', '172.16.1.0/24 172.16.2.0/24', 'B’s subnet (172.16.2.0/24), as shown in the top arrow lines in Figure 18-3.']
# 11
# ['Figure 18-2 Standard ping 172.6.2.101 Command Using the Source Interface IP Address', 'R1 R2', 'B', '.101', 'SW1 .2 SW2', 'A G0/0/0', '172.16.2.0/24', 'Echo Reply', 'Echo Request', '172.16.1.0/24 172.16.4.1', 'Figure 18-2 shows the packet flow.']
# 12
# ['Figure 18-1 Concept Behind ping 172.16.2.101 on Host A', 'SW1 R1 R2 SW2', 'IP 2', 'Echo Reply', 'ICMP', '1 IP', 'Echo Request', 'ICMP', 'A', '172.16.1.51 172.16.2.101', 'B', 'receives the messages and sends back an echo reply (Step 2).']
# 23
# ['Figure 17-7 Design Used in EtherChannel Configuration Examples', 'G1/0/14', 'G1/0/13', 'G1/0/14', 'G1/0/13', 'SW1 SW2', 'no switchport', 'ip address 10.1.12.2 255.255.255.0', 'interface port-channel 12', 'Subnet 10.1.12.0/24', 'no switchport', 'ip address 10.1.12.1 255.255.255.0', 'interface port-channel 12', 'Po12 Po12', 'Fa0/21', 'Fa0/22', 'Fa0/24', 'Fa0/23', 'Subnet 10.1.2.0/24', 'VLAN 2', 'Subnet 10.1.3.0/24', 'VLAN 3', '10.1.12.0/24.']
# 18
# ['Figure 17-6 Two Links Between Each Distribution and Core Switch', 'Routed Interfaces', 'Point-to-Point, Layer 3 Distribution & Core', 'Layer 2 Access: SVIs', 'Core2 D22', 'Core1 D21', 'D12', 'D11', 'Layer 2 Access: SVIs', 'A24', 'A23', 'A22', 'A21', 'A14', 'A13', 'A12', 'A11', 'and core switches, as shown in Figure 17-6.']
# 18
# ['Figure 17-5 Using Routed Interfaces for Core and Distribution Layer 3 Links', 'Routed Interfaces', 'Layer 2 Access: SVIs', 'Core2 D22', 'Core1 D21', 'D12', 'D11', 'Layer 2 Access: SVIs', 'Point-to-Point, Layer 3 Distribution & Core', 'A24', 'A23', 'A22', 'A21', 'A14', 'A13', 'A12', 'A11', 'ports and some SVIs.']
# 22
# ['Figure 17-4 Routing on a Routed Interface on a Switch', 'Interface', 'Routed', 'F0/4', 'F0/3', 'F0/2', 'F0/1', 'the Layer 3 Switch', 'The Rectangle Represents', 'B1', '10.1.30.2', 'G0/0', '10.1.30.1/24', 'interface G0/1', 'Not a VLAN!', 'VLAN 10', '10.1.10.1/24', 'interface vlan 10', '10.1.20.1/24', 'interface vlan 20', 'VLAN 20', 'could configure that link as a routed port, as shown in the figure.']
# 20
# ['Figure 17-3 Routing on VLAN Interfaces in a Layer 3 Switch', 'F0/4', 'F0/3', 'F0/2', 'F0/1', 'G0/1', 'with Internal Logic Visible', 'The Middle Box Represents the Layer 3 Switch,', 'B1', '10.1.30.2', 'G0/0 10.1.30.1/24', 'interface vlan 30', 'VLAN 30', 'VLAN 10', '10.1.10.1/24', 'interface vlan 10', '10.1.20.1/24', 'interface vlan 20', 'VLAN 20', 'that the switch routes the packets.']
# 10
# ['Figure 17-2 Subinterfaces on Router B1', 'B1 SW1', '20 10 20 10 20', 'VLAN 10', 'VLAN 20', 'Interface G0/0.20', 'Interface G0/0.10', '10.1.10.1/24', '10.1.20.1/24', 'came in or out G0/0.20.']
# 18
# ['Figure 17-1 Layer 3 Switching at the Central Site', 'SW3', 'SW2', 'C B', 'D A', 'SW1', 'B3', '2 VLANs', 'B2', '2 VLANs', 'Core', 'B1', '12 VLANs', 'VLAN Trunking', 'Switches', 'Layer 3', '2 VLANs', 'network. Figure 17-1 shows cases in which these options could be used.']
# 7
# ['Figure 16-14 Example Use of Static Default Routes at 1000 Low-Speed Remote Sites', 'Packets to Core', 'Send All Non-local', 'B1000', 'B1', 'Core', '....']
# 14
# ['Figure 16-13 Using a Floating Static Route to Key Subnet 172.16.2.0/24', '172.16.2.0/24', 'EoMPLS Subnet', 'Backup Link (T1; Static)', 'Primary Link (OSPF)', 'Network', 'Enterprise', 'Core of the', 'S0/0/1', 'G0/0', 'R2', 'R1', 'R3', 'route.']
# 23
# ['Figure 16-12 Sample Network Used in Static Route Configuration Examples', 'R3', 'R1', 'G0/0/0', 'G0/1/0', 'S0/0/1', 'S0/0/0', '.3', '.2', '.1', '.1', 'R2', 'Subnet 172.16.5.0/24', 'Subnet 172.16.3.0/24', '.3 C .9 G0/0', 'Subnet 172.16.2.0/24', 'Subnet 172.16.4.0/24', 'Subnet 172.16.1.0/24', '.2 B .9 G0/0', '.9 G0/0', '.1', 'A', 'figure.']
# 13
# ['Figure 16-11 Static Route Configuration Concept', '.9', '1', 'R1 R2', '.1', 'G0/0', '.2 2', 'S0/0/0 172.16.4.2 G0/0 .9', '172.16.2.0/24', 'For Packets Destined to this Subnet', 'Send out Here or… Send to There', '172.16.1.0/24 172.16.4.0/24', 'address (172.16.4.2).']
# 24
# ['Figure 16-10 Sample Network to Show Connected Routes', 'R3', 'R1', 'G0/0/0', 'G0/1/0', 'S0/0/1', 'S0/0/0', '.3', '.2', '.1', '.1', 'R2', 'Subnet 172.16.5.0/24', 'Subnet 172.16.3.0/24', '.3 C .9 G0/0', 'Subnet 172.16.2.0/24', 'Subnet 172.16.4.0/24', 'Subnet 172.16.1.0/24', '.2 B .9 G0/0', '.9 G0/0', '.1', 'A', 'Technet24', 'c as the route code, meaning connected.']
# 15
# ['Figure 16-9 Routing Step 4 on Router R1 with a LAN Outgoing Interface', 'R1 R3', 'Eth IP Packet Eth', 'To: 0200.0303.9999', '172.16.5.3 0200.0303.9999 To: 172.16.3.9', 'ARP Table', 'Subnet 172.16.5.0/24 Subnet 172.16.3.0/24', 'G0/0', 'G0/1/0 G0/0/0 C', '.3 .3 .9', 'Subnet 172.16.1.0/24', '.9 G0/0', '.1 .1', 'A', 'would first have to use ARP to learn the matching MAC address.']
# 11
# ['Figure 16-8 Routing Step 4 on Router R1: Encapsulating the Packet', 'IP Packet', 'HDLC IP Packet HDLC', 'G0/0', 'S0/0/1', 'Router R1', 'S0/0/0', 'To: 172.16.2.9', 'IP', 'HDLC IP HDLC', 'HDLC frame, as shown in Figure 16-8.']
# 32
# ['Figure 16-7 Routing Step 3 on Router R1: Matching the Routing Table', 'G0/0 IP Packet', '/24', '/24', '/24', '/24', '/24', 'G0/1/0', 'S0/0/0', 'G0/1/0', 'S0/0/0', 'None', 'None', 'None G0/0', '172.16.4.2', '172.16.5.3', '172.16.5.0', '172.16.1.0', '172.16.3.0', '172.16.4.0', 'Out Interface', 'Forwarding', 'IPv4 Routing Table', '172.16.2.9', 'Matching', 'Subnet Mask Next Router', '172.16.2.0', 'S0/0/1', 'Router R1', 'S0/0/0', 'IP', 'where to send the packet next.']
# 11
# ['Figure 16-6 Routing Step 2 on Router R1: De-encapsulating the Packet', 'IP Packet Eth', 'Packet', 'IP', 'S0/0/1', 'Router R1', 'S0/0/0', 'G0/0', 'To: 172.16.2.9', 'Eth IP Eth', 'remains unchanged (172.16.2.9).']
# 13
# ['Figure 16-5 Routing Step 1, on Router R1: Checking FCS and Destination MAC', 'Eth IP Packet Eth', 'S0/0/1', 'Router R1', 'S0/0/0', '0200.0101.0101', '172.16.1.1', 'G0/0', 'frame unchanged?', 'FCS: Is this', 'Is this my G0/0 MAC?', '0200.0101.0101', 'in the figure represents the internals of Router R1.).']
# 15
# ['Figure 16-4 Host A Sends Packet to Host B', 'R1', 'A', 'IP Packet', 'G0/0', '0200.0101.0101', '172.16.1.1', '172.16.1.1 0200.0101.0101', 'ARP Table', 'GW=172.16.1.1', 'IP=172.16.1.9/24', 'To: 0200.0101.0101', 'To: 172.16.2.9', 'Eth Eth', 'all the detail of the Layer 2 switches.']
# 23
# ['Figure 16-3 IPv4 Network Used to Show Five-Step Routing Example', 'R3', 'R1', 'G0/0/0', 'S0/0/1', 'G0/1/0', 'S0/0/0', '.3', '.2', '.1', '.1', 'R2', 'Subnet 172.16.5.0/24', 'Subnet 172.16.3.0/24', '.3 C .9 G0/0', 'Subnet 172.16.2.0/24', 'Subnet 172.16.4.0/24', 'Subnet 172.16.1.0/24', '.2 B .9 G0/0', '.9 G0/0', '.1', 'A', '172.16.5.1 on an Ethernet WAN interface.']
# 18
# ['Figure 16-2 Router Routing Logic Summary', 'IP Packet w/ Data', 'IP Packet w/ Data', '3', '2 4', '1 5', 'FCS (Ethernet Trailer)', 'IP Packet w/ Data', 'To R1 (Ethernet Header)', 'To C (IP Header', 'Eth Eth', 'To R2', 'To C', 'HDLC HDLC', 'Router R1', 'Ethernet HDLC', 'Routing Table', 'encapsulated inside an Ethernet frame (both header and trailer).']
# 12
# ['Figure 16-1 Host Routing Logic Summary', 'R1', 'Local', 'Remote', 'D', 'A', 'SW1', 'B', 'Network', 'IPv4', 'Rest of', 'terms default gateway and default router are synonyms.).']
# 18
# ['Figure 15-6 IPv4 Addresses Used in Example 15-2', 'R1', 'R3', 'G0/0 G0/1', 'S0/0/0', '172.16.5.1', '172.16.4.1 R2', '.11 .1', '.1', '.1', '172.16.1.___', '172.16.3.___', '.102', '.101', '172.16.2.___', '.102', '.101', 'Example 15-2 showing the matching configuration.']
# 10
# ['Figure 15-5 SOHO Network, Using Cable Internet and an Integrated Device', 'UTP', 'R1 ISP/Internet', 'SOHO', '(Coaxial)', 'Cable', 'CATV', 'UTP', 'Technet24', 'the cable modem.']
# 12
# ['Figure 15-4 Devices in a SOHO Network with High-Speed CATV Internet', 'Access Point', 'Switch Router', 'UTP', 'R1 ISP/Internet', 'Internal Functions', 'SOHO Router', 'UTP UTP', 'UTP Cable Modem', 'Cable', 'CATV', 'WAN access through a cable Internet connection.']
# 12
# ['Figure 15-3 Photos of a Model 4321 Cisco Integrated Services Router (ISR)', 'On/Off', 'USB', '(RJ-45 or SFP)', 'Gi0/0', 'Console', 'RS-45', '2 NIM Slots', 'Aux', 'Gi0/1', '2-Port Serial NIM', 'items as well, including both an RJ-45 and USB console port.']
# 26
# ['Figure 15-2 More Detailed Cabling Diagram for the Same Enterprise Network', 'CSU/DSU', 'External', '1 2', 'IP', 'R1', 'Cables', 'UTP', 'Central Site', '3', 'Cables', 'UTP', 'DSU R2', 'CSU/', 'Serial Cable', 'CSU/DSU', 'Internal', 'Servers', 'Line', 'Leased', 'Branch Office', 'S1 S2', '6', '5', '4', 'UTP cable to both the router and the nearby LAN switch.']
# 25
# ['Figure 15-1 Generic Enterprise Network Diagram', 'R3', 'R1', 'G0/0/0', 'G0/1/0', 'S0/0/1', 'S0/0/0', '.3', '.2', '.1', '.1', 'R2', 'Subnet 172.16.5.0/24', 'Subnet 172.16.3.0/24', 'G0/0', '.3', 'Subnet 172.16.2.0/24', 'Subnet 172.16.4.0/24', 'Subnet 172.16.1.0/24', 'G0/0', '.2', 'G0/0', '.1', 'Technet24', 'point-to-point serial link as introduced in Chapter 3.']
# 9
# ['Figure 14-12 Find the Subnet Broadcast: 192.168.5.64, 255.255.255.224', 'Action', '192 168 5 64', '255 . . . 224', '32', '–224', '256', '255 255', '. . .']
# 9
# ['Figure 14-11 Find the Subnet Broadcast: 130.4.96.0, 255.255.240.0', 'Action', '0-255', 'ID 130 4 96 0', '255 . . . 0 16', '–240', '256', '255 240', '. . .']
# 16
# ['Figure 14-10 Resident Subnet for 192.168.5.77, 255.255.255.224', 'Multiples:', '0 32 64 96 128 160 192 224', 'IP', 'Action Copy Copy Copy Magic', '255 . . . 224', '32', '–224', '256', '255 255', '192 . 168 . 5 . 77', '1 1 1 3', '192 . 168 . 5 . 64', '0-255', 'ID', 'therefore, the subnet ID ends with 64, for a value of 192.168.5.64.']
# 15
# ['Figure 14-9 Find the Subnet ID: 130.4.102.1, 255.255.240.0', 'Multiples:', '0 16 32 48 64 80 96 112 128', 'IP', 'Action Copy Copy Magic Zero', '255 . . . 0 16', '–240', '256', '255 240', '130 . 4 . 102 . 1', '1 1 3 2', '130 . 4 . 96 . 0', '0-255', 'ID', 'the written process to find the subnet ID, as listed in the previous few pages.']
# 15
# ...
# 4
# ['Figure 5-1 Campus LAN and Data Center LAN, Conceptual Drawing', 'Campus LAN Data Center LAN', 'Technet24', 'forward the frame, and so on.']
# 16
# ['Figure 4-9 Cisco Switch Memory Types', 'Configuration)', '(Startup', 'NVRAM', 'Program)', '(Bootstrap', 'ROM', 'Software)', '(Cisco IOS', 'Flash', 'Configuration)', 'Running', 'Memory and', '(Working', 'RAM', 'memorization and study.']
# 28
# ['Figure 4-8 Navigation In and Out of Switch Configuration Modes', 'Mode', 'VTY Line', 'exit', 'line vty 0 15', 'Mode', 'Console Line', 'exit', 'line console 0', 'Mode', 'VLAN', 'exit', 'vlan x', 'Mode', 'Config', 'Global', 'Mode', 'Enable', 'End or Ctl-Z', 'terminal', 'configure', 'Mode', 'Interface', 'exit', 'End or Ctl-Z', 'interface type/number', 'Technet24', 'listed in bold in the center of the figure.']
# 9
# ['Figure 4-7 CLI Configuration Mode Versus EXEC Modes', 'Enable Mode', 'disable', 'enable', 'User Mode Configuration Mode', 'end or Ctl-Z', 'configure terminal', 'Technet24', 'privileged EXEC mode.']
# 10
# ['Figure 4-6 User and Privileged Modes', '(Privileged Mode)', 'Enable Mode', 'Disable (Command)', 'Enable (Command)', 'SSH', 'Telnet', 'Console', 'User Mode', 'if it is the hostname followed by the #, the user is in enable mode.']
# 2
# ['Figure 4-5 Terminal Settings for Console Access', 'listed just before this paragraph.']
# 4
# ['Figure 4-4 A Part of a 2960-XR Switch with Console Ports Shown', 'RJ-45 Console', 'USB Console (Mini-B)', 'seen rectangular standard USB Type A port.']
# 19
# ['Figure 4-3 Console Connection to a Switch', 'SW1 SW2 SSWW33', 'USB Cable', 'USB Port', 'USB Console', '3', 'SW2', 'Rollover Cable', 'USB Cable', 'USB Converter', 'USB Port', 'RJ-45 Console', '2', 'SW1', 'Rollover Cable', 'Serial Port', 'RJ-45 Console', '1', 'the far right side of Figure 4-3.']
# 13
# ['Figure 4-2 CLI Access Options', 'TCP/IP Network', 'or USB', 'Serial', 'or USB', 'RJ-45', '(Short) Console Cable', 'Telnet and SSH', '2960 Switch', 'Interface', 'User Mode', 'Console', 'access to the CLI. Figure 4-2 depicts the options.']
# 3
# ['Figure 4-1 Cisco 2960-XR Catalyst Switch Series', 'Technet24', 'or 1000BASE-T (1 Gbps) Ethernet.']
# 7
# ['Figure 3-16 Sample Network, ping Command', 'Eth IP ICMP Echo Reply', 'Eth IP ICMP Echo Request', 'Harold', 'ping Harold', 'Hannah', 'process.']
# 22
# ['Figure 3-15 Sample ARP Process', 'Unicast (to R3)', 'Ethernet', 'Broadcast', 'Ethernet', '2', '1', 'Sender MAC = 0200.2222.2222', 'Sender IP = 150.150.4.10', 'Target Mac = R3’s MAC', 'Target IP = R3’s IP', 'Target MAC = ???', 'Target IP = 150.150.4.10', 'Sender MAC = R3’s MAC', 'Sender IP = R3’s IP', 'ARP Request', 'ARP Reply', 'R3', 'PC2', '0200.2222.2222', '150.150.4.10', 'ARP Requests can be seen.']
# 21
# ['Figure 3-14 Basic DNS Name Resolution Request', 'Name Database', 'DNS Server', 'Network Server1 = 10.1.2.3', 'TCP/IP', '10.1.2.6', '10.1.2.3', 'Address', 'Server2', 'Server1', 'Name', 'IP Address of Server1?', '10.1.2.3', 'Server1', '3', '2', 'PC11 1', 'Server', 'DNS', '11', '10.1.2.3, the address used by Server1.']
# 32
# ['Figure 3-13 Example of How Routing Protocols Advertise About Networks and Subnets', '150.150.4.0', 'Subnet', 'R1', 'PC11', 'PC2', 'PC1', 'R3', 'R2', 'B', 'R3 Routing Table', '150.150.4.0 Gigabit0/0 N/A', 'Subnet Interface Next Hop', 'D', 'F', 'E', 'A', 'C', 'F0/0', '150.150.4.10', '150.150.3.1', '150.150.2.7', 'S0', 'G0/0', 'R2 Routing Table', '150.150.4.0 FastEth0/0 150.150.3.1', 'Subnet Interface Next Hop', 'R1 Routing Table', '150.150.4.0 Serial0 150.150.2.7', 'Subnet Interface Next Hop', 'Technet24', 'the figure.']
# 8
# ['Figure 3-12 IPv4 Header, Organized as 4 Bytes Wide for a Total of 20 Bytes', '4 Bytes', 'Destination IP Address', 'Source IP Address', 'Time to Live Protocol Header Checksum', 'Identification Flags Fragment Offset', 'Version Length DS Field Packet Length', 'IP header remains, with the IP addresses unchanged by the IP routing process.']
# 33
# ['Figure 3-11 Network Layer and Data-Link Layer Encapsulation', 'Eth IP Packet Eth', 'Eth IP Packet Eth', 'HDLC IP Packet HDLC', 'Eth IP Packet Eth', 'F0/0', '150.150.3.1', 'PC2 150.150.4.10', 'PC1', '150.150.1.10', 'R3 Routing Table', '150.150.4.0 Gigabit0/0 N/A', 'Subnet Interface Next Hop', 'R2 Routing Table', '150.150.4.0 FastEth0/0 150.150.3.1', 'Subnet Interface Next Hop', 'R1 Routing Table', '150.150.4.0 Serial0 150.150.2.7', 'Subnet Interface Next Hop', 'D', 'C', 'B', 'A', '150.150.4.0', 'Subnet', 'R3', 'R2', 'R1', '150.150.2.7', 'G0/0', 'S0', '150.150.1.4', 'how PC1 and each of the three routers builds the appropriate new data-link headers.']
# 24
# ['Figure 3-10 Routing Logic: PC1 Sending an IP Packet to PC2', 'IP Packet', 'IP Packet', 'IP Packet', 'My Route Says: Send Directly to PC2', 'My Route Says: Send to R3', 'My Route Says: Send to R2', 'Destination Is in Another Group; Send to Nearby Router', 'IP Packet', 'R1', 'PC1', '150.150.1.10', 'EoMPLS', 'Serial', '150.150.4.0', 'Subnet', 'PC2', 'R3', 'R2', 'F0/0', '150.150.4.10', 'S0', 'G0/0', 'the example in Figure 3-10.']
# 13
# ['Figure 3-9 Routing over an EoMPLS Link', '802.3 IP Packet 802.3 Header Trailer', '802.3 IP Packet 802.3 Header Trailer', '802.3 IP Packet 802.3 Header Trailer', 'Destination = R2 G0/0 MAC', 'Source = R1 G0/1 MAC', 'G0/1 G0/0', '1 2 3', 'R1 R2', 'PC2', 'LAN1 EoMPLS WAN LAN2', 'PC1', 'an Ethernet WAN link, rather than an Ethernet LAN link.']
# 9
# ['Figure 3-8 EoMPLS Acting Like a Simple Ethernet Link Between Two Routers', 'G0/1 G0/0', 'Ethernet Link', 'Fiber Optic', 'R1 R2', 'PC2', 'Ethernet LAN EoMPLS WAN Ethernet LAN', 'PC1', 'logically, the two routers can send Ethernet frames to each other over the link.']
# 23
# ['Figure 3-7 Fiber Ethernet Link to Connect a CPE Router to a Service Provider’s WAN', 'CPE CPE', 'Access Link', 'Ethernet', 'Fiber', 'Site', 'Customer', 'Site', 'Customer', 'PoP', 'Provider', 'Service', 'PoP', 'Provider', 'Service', 'R1 SP1 SP2 R2', 'Service', 'Ethernet WAN', 'Service Provider’s', 'Access Link', 'Ethernet', 'Fiber', 'and the SP’s network, as shown in Figure 3-7.']
# 12
# ['Figure 3-6 General Concept of Routers De-encapsulating and Re-encapsulating IP', '802.3 IP Packet 802.3 Header Trailer', 'HDLC IP Packet HDLC Header Trailer', 'Header Trailer', '1 2 3', '802.3 IP Packet 802.3', 'R1 R2', 'PC2', 'LAN1 HDLC LAN2', 'PC1', 'Technet24', 'to R2, and from R2 to PC2.']
# 11
# ['Figure 3-5 IP Routing Logic over LANs and WANs', 'To PC2 To PC2 To PC2 R1 R2', 'Send to PC2 Next', 'Final Destination PC2?', 'Send to R2 Next', 'Final Destination PC2?', 'Send to R1 Next', 'Final Destination PC2?', '1 LAN 2 WAN 3 LAN', 'PC1 PC2', 'to the next router or end-user device. Figure 3-5 shows that network layer perspective.']
# 10
# ['Figure 3-4 HDLC Framing', 'Type', 'FCS', 'Data', 'Control', 'Address', 'Flag', 'Bytes 1 1 1 2 Variable 2', 'Proprietary Cisco HDLC (Adds Type Field)', 'use a Cisco-proprietary variation of HDLC that adds a Type field, as shown in Figure 3-4.']
# 12
# ['Figure 3-3 Possible Cabling Inside a Telco for a Short Leased Line', 'R1 Switch-1 Switch-2 R2', 'Site2', 'Customer', 'CO2', 'Telco', 'CO1', 'Telco', 'Underground', 'Site1', 'Customer', 'of a crossover cable between the two routers.']
# 10
# ['Figure 3-2 Conceptual View of the Leased-Line Service', 'SW22', 'SW21', 'SW12', 'SW11', 'R1 R2', 'Building 2', '1000 Miles', 'Building 1', 'pair for each direction of sending data, which allows full-duplex operation.']
# 6
# ['Figure 3-1 Small Enterprise Network with One Leased Line', 'R1 R2', 'PC2', 'LAN WAN LAN', 'PC1', 'of the line.']
# 11
# ['Figure 2-24 Full and Half Duplex in an Ethernet LAN', 'Hub', 'SW1 SW2 F0/2', 'A B C', 'Full Full Half', 'Half', 'Full', 'Full', 'Full', 'Full', 'PCs connected to the hub.']
# 9
# ['Figure 2-23 Collision Occurring Because of LAN Hub Behavior', '2 1A', '1B', 'Collision!', 'Hub 1', 'Bob', 'Archie', 'Larry', 'Larry on the left (Step 2).']
# 19
# ['Figure 2-22 Example of Sending Data in a Modern Ethernet LAN', 'SW1 SW2', '1 2', 'F0/2', 'Full', '100BASE-T', 'Eth Data Eth', '4', 'Eth Data Eth', '3', '1', '2', 'Full', '10BASE-T', 'Dest = PC2', 'Source = PC1', 'G0/1 1000Base-T', 'Full', 'frame to PC2.']
# 10
# ['Figure 2-21 Use of Ethernet Type Field', 'SW1 R1', 'Eth Trailer', 'Type = 86DD', 'Eth Header IPv6', 'Eth Trailer', 'Type = 0800', 'Eth Header IPv4', 'Technet24', 'using the values reserved by the IEEE, as shown in Figure 2-21.']
# 12
# ['Figure 2-20 Structure of Unicast Ethernet Addresses', 'Example', 'Size, in hex digits', 'Size, in bits', '(NIC Cards, Interfaces)', 'Vendor Assigned', 'Identifier (OUI)', 'Organizationally Unique', '00 60 2F 3A 07 BC', '6 Hex Digits 6 Hex Digits', '24 Bits 24 Bits', 'Figure 2-20 shows the structure of the unicast MAC address, with the OUI.']
# 17
# ['Figure 2-19 Commonly Used Ethernet Frame Format', '4', 'FCS', '46 – 1500', 'Data and Pad', '2', 'Type', '6', 'Source', 'Bytes 6', 'Header Trailer', 'Destination', '1', 'SFD', '7', 'Preamble', 'being commonly used today.']
# 6
# ['Figure 2-18 Two Fiber Cables with Tx Connected to Rx on Each Cable', 'Tx', 'Rx', 'Rx', 'Tx', 'connects to a receive port on the other device, and vice versa with the other cable.']
# 5
# ['Figure 2-17 Transmission on Single-Mode Fiber with Laser Transmitter', 'Laser Core', 'Cladding', 'Cladding', 'laser-based transmitter sends light at a single angle (hence the name single-mode).']
# 5
# ['Figure 2-16 Transmission on Multimode Fiber with Internal Reflection', 'LED Core', 'Cladding', 'Cladding', 'the core as it travels through the core.']
# 8
# ['Figure 2-15 Components of a Fiber-Optic Cable', 'Outer Jacket', 'Strengthener', 'Buffer', 'Cladding', 'Core', 'Technet24', 'Figure 2-15 shows a cutout with the components of a fiber cable for perspective.']
# 19
# ['Figure 2-14 Four-Pair Straight-Through Cable to 1000BASE-T', 'PC Switch', '8', '7', '5', '4', '6', '3', '2', '1', '8', '7', '5', '4', '6', '3', '2', '1', 'shown in Figure 2-14.']
# 16
# ['Figure 2-13 Typical Uses for Straight-Through and Crossover Ethernet Cables', 'Switch 22', 'Switch 21', 'Switch 12', 'Switch 11', 'Cables', 'Crossover', 'Cables', 'Through', 'Straight-', 'Building 2', 'Cables', 'Through', 'Straight-', 'Building 1', 'the switches require crossover cables.']
# 10
# ['Figure 2-12 Crossover Ethernet Cable', 'RJ-45 Pins', '3,6 3,6', '1,2 1,2', '3 2 1', '6', '3 2 1', '6', 'RJ-45 Pins', 'and the bottom half shows a conceptual diagram.']
# 8
# ['Figure 2-11 Ethernet Straight-Through Cable Concept', '(3,6) (3,6)', 'NIC', 'Straight-Through Cable', '(1,2) (1,2)', 'Switch', 'Larry', 'pairs and pins.']
# 13
# ['Figure 2-9 Using One Pair for Each Transmission Direction with 10- and 100-Mbps', 'Receiver', '6 6', '3 3', '2 2', '1 One Twisted Pair 1', 'Transmitter Data Flow', 'Transmitter', 'One Twisted Pair', 'Receiver Data Flow', 'PC Switch', 'Technet24', 'top pair, and the switch on the right transmits using the bottom pair.']
# 6
# ['Figure 2-7 RJ-45 Connectors and Ports (Ethernet NIC © Oleg Begunenko/123RF,', 'LAN Switch', 'Ethernet NIC', 'RJ-45 Connector', 'RJ-45 Ports', 'to the Ethernet LAN. Figure 2-7 shows photos of the cables, connectors, and ports.']
# 9
# ['Figure 2-6 Basic Components of an Ethernet Link', 'Port', 'RJ-45', 'Port', 'RJ-45', 'RJ-45 Connectors', 'Cable with Wires Inside', 'Node Node', 'and the matching ports on the devices into which the connectors will be inserted.']
# 7
# ['Figure 2-5 Creating One Electrical Circuit over One Pair to Send in One Direction', 'Other Wire, Same Pair', 'Receiver', 'One Wire in a Pair', 'Transmitter Electrical Current', 'Node 1 Node 2', 'Ethernet ports, connect the wires in one pair to complete a loop, allowing electricity to flow.']
# 22
# ['Figure 2-4 Ethernet LAN Forwards a Data-Link Frame over Many Types of Links', '2 3', 'SW3 4', '3', 'UTP', '100 Mbps', 'SW2', '2', '200m 1km', 'Fiber', '10 Gbps', 'Fiber', '1 Gbps', 'UTP', '1 Gbps', '1 Eth Data Eth', 'Eth Data Eth', 'SW1', '1', 'UTP', '10 Mbps', '100 Mbps, respectively.']
# 15
# ['Figure 2-3 Single-Building Enterprise Wired and Wireless LAN', 'SW1 SWD', 'PC1', 'SW2', 'PC2', 'SW3', 'Network', 'Enterprise', 'To Rest of', '1st Floor', '2nd Floor', '3rd Floor', 'Building', 'PC3', 'switch (SWD) and then back up through switch SW2 on the second floor.']
# 8
# ['Figure 2-2 Typical Small Wired and Wireless SOHO LAN', 'Router', 'To Internet', 'Switch Access Point', 'F0/1', 'Tablets', 'F0/2', 'does all these functions.']
# 9
# ['Figure 2-1 Typical Small Ethernet-Only SOHO LAN', 'Router', 'Switch', 'F0/1', 'F0/2', 'F0/3', 'To Internet', 'F0/4', 'Internet.).']
# 16
# ['Figure 1-15 OSI Encapsulation and Protocol Data Units', 'L2PDU', 'L3PDU', 'L4PDU', 'L5PDU', 'L6PDU', 'L7PDU', 'L2H Data L2T', 'L3H Data', 'L4H Data', 'L5H Data', 'L6H Data', 'L7H Data', 'L#T - Layer # Trailer', 'L#H - Layer # Header', 'Figure 1-15.']
# 27
# ['Figure 1-14 OSI Model Compared to the Two TCP/IP Models', '1', '2', '3', '7', '6', '5', '4', 'Physical', 'Data Link', 'Network', 'Application', 'Presentation', 'Session', 'Transport', '1', '2', '3', '4', '5 - 7', 'Physical', 'Data Link', 'Network', 'Transport', 'Application', 'OSI TCP/IP', 'TCP/IP models.']
# 8
# ['Figure 1-13 Perspectives on Encapsulation and “Data”1', 'Frame', 'Packet', 'Segment', 'LH Data LT', 'IP Data', 'TCP Data', 'layer. Figure 1-13 shows each layer along with the associated term.']
# 24
# ['Figure 1-12 Five Steps of Data Encapsulation: TCP/IP', 'TCP Data', '4', '5', '4', '3', '2', '1', '5', '4', '3', '2', '1', 'Transmit Bits', 'IP TCP Data', 'TCP Data', 'Data', 'Data Link IP Data Link', 'Physical', 'Data Link', 'Network', 'Transport', 'Application', 'also at times add a header as well.']
# 3
# ['Figure 1-11 Larry Using Ethernet to Forward an IP Packet to Router R1', 'Header Trailer', 'Ethernet IP Packet Eth.']
# 22
# ['Figure 1-10 Basic Routing Example', 'R2', 'R3', 'R1', 'Destination 2.2.2.2', 'Source 1.1.1.1', 'IP TCP HTTP', '2.2.2.2', 'Bob', 'R1', 'Always to', 'Send Locally', 'To 2._____', 'Send to R2', 'To 2._____', '1 2 3', '1.1.1.1', 'Larry', 'Addresses: 2._____', '1', 'Technet24', 'address (1.1.1.1) and a destination IP address of Bob’s IP address (2.2.2.2).']
# 14
# ['Figure 1-9 Simple TCP/IP Network: Three Routers with IP Addresses Grouped', 'Archie', 'R2', 'R3', 'R1', '2.2.2.2', 'Bob', '3.3.3.3', '1.1.1.1', 'Larry', 'Addresses: 2.__.__.__', 'Addresses: 3.__.__.__', 'Addresses: 1.__.__.__', 'part of the network infrastructure is included.']
# 6
# ['Figure 1-8 Postal Service Forwarding (Routing) Letters', 'California', 'Postal Service', 'Local 1', 'Technet24', 'each letter next, as shown in Figure 1-8.']
# 25
# ['Figure 1-7 TCP Error-Recovery Services as Provided to HTTP', 'TCP', 'Send 2 Next 4', '3', 'Data', 'Rest of Web Page', 'TCP', 'SEQ = 3', 'Data Lost!', 'More Web Page', 'TCP', 'SEQ = 2 2', 'Data', 'Web Page', 'HTTP', 'OK', 'TCP', 'SEQ = 1 1', 'Bob', 'Browser', 'Web', 'Larry', 'Server', 'Web', 'notices lost data and asks the sender to try again.']
# 18
# ['Figure 1-6 HTTP GET Request, HTTP Reply, and One Data-Only Message', 'More of file home.htm 3', 'Data', 'home.htm', 'Data', 'OK', 'HTTP Header', '2', 'GET home.htm', 'HTTP Header', '1', 'Bob', 'Browser', 'Web', 'Larry', 'Server', 'Web', 'that HTTP is used to transfer the web pages.']
# 7
# ['Figure 1-5 Basic Application Logic to Get a Web Page', '2', '1', 'Here is the file home.htm', 'Give me your web page', 'Web Server - Larry Web Browser - Bob', 'Figure 1-5.']
# 8
# ['Figure 1-4 The TCP/IP Networking Models', 'Physical', 'Data Link', 'Network', 'Transport', 'Application', 'TCP/IP Model', 'that category of functions, as shown in Figure 1-4.']
# 14
# ['Figure 1-3 Historical Progression: Proprietary Models to the Open TCP/IP Model', '2000s', 'TCP/IP', '1990s', 'Vendor', 'Other', 'Vendor', 'Other', 'TCP/IP', 'IBM DEC', '1980s', 'IBM DEC 1', 'Technet24', '1 D and F 2 A and G 3 B 4 B 5 A 6 D 7 B.']
# 7
# ['Figure 1-2 Example Representation of an Enterprise Network', 'SW1', 'Wireless', 'Cable', 'Ethernet', 'Enterprise Network', 'on an enterprise network.']
# 8
# ['Figure 1-1 End-User Perspective on High-Speed Internet Connections', 'Wireless DSL', 'Cable', 'CATV', 'Cable', 'Ethernet', 'The Internet', 'shown in Figure 1-1.']
# 35862 33
# 16 338 35862

# %%
import re

s = '''
11111.
22222
33333

44444
55555
|||||
66666
'''
l = s.split('\n')
def mFigure(l1, l2):
    l1.reverse()
    print(l1)
    pass
l2 = []
mFigure(l, l2)
# Out:
# ['', '66666', '|||||', '55555', '44444', '33333', '22222', '11111', '']

# %% [markdown]
# <hr>

# %% [markdown]
# ## tests
# ## test1

# %%
import re

def mFromPdf(l1, l2):
    '''
    '1','2.' => '1 2.'
    '''
    l1.append('11')
    l3 = []
    e0 = l1[0]
    for i in range(1, len(l1)):
        e = l1[i]
        match1 = re.search('\w$', e0)
        match2 = re.search('^[-#]', e0)
        match = match1 and not match2
        if match:
            e0 += ' '+ e
        else:
            l3.append(e0)
            e0 = e
    for e in l3:
        l2.append(e)
    pass

def mToSentence(l1, l2):
    l3 = []
    
    
    for e in l1:
        match = re.search('^[#-]', e)
        if match:
            l3.append(e)
        else:
            l3.append('')
            m = re.split(r'(?<=[^A-Z].[.?!]) +(?=[A-Z])', e)
            l3 += m
            pass
    for e in l3:
        l2.append(e)
    pass

s = mReadFile('x15t3a.txt')
l = []
mList(s, l)
l2 = []
mFromPdf(l, l2)
l3 = []
mToSentence(l2, l3)
s2 = '\n'.join(l3)
mWriteFile('x15t3b.txt', s2)
# print(s[:320])
print(len(l3))
# Out:
# 608

# %% [markdown]
# ## paragraph

# %%
s = '''

## 1
## 2
- 3
21

22
## 3
31
32
## 4
41
42
'''

# %%
def mTranslateList(lien, liru):
    sen = '\n'.join(lien)
    sru = translate(sen)
    liru2 = sru.split('\n')
    for i in range(len(lien)):
        e = ''
        if i<(len(liru2)):
            e = liru2[i]
        liru.append(e)

def mToParagraph(l1, l2):
    '''
    and translate
    '''
    while l1[0].strip() == '':
        l1 = l1[1:]
    l1.append('11')
    l3 = []
    lpre = []
    epre = ''
    lpar = []
    fl = 0
    lall = []
#     print(l1)
    for i in range(0, len(l1)):
        e = l1[i]
        epre = ''
        match = re.search('^[#-]+', e)
        if match or i == len(l1)-1:
            if match:
                epre = match[0]
                e2 = re.sub(f'^{match[0]}', '', e)
            else:
                e2 = e
            if fl > 1:
#                 = all =
#                 print(lpar)
#                 print(lpre)
                lparru = []
                mTranslateList(lpar, lparru)
                once = 0
                for i in range(len(lpar)):
                    if len(lpre[i]) > 0 and i < len(lpre):
                        if lpre[i][0] == '#' or lpre[i][0] == '-' :
                            lall.append(lpre[i] + ' ' + lpar[i])
                            lall.append(lparru[i] + '   ')
                        once = 0 
                    else:
                        if once == 0:
                            lall.append('__|__')
                            lall.append('--|--')
                            once = 1
                        lall.append(f'{lpar[i]}|{lparru[i]}')
#                 print(lparru)

                fl = 0
                lpar = []
                lpre = []
            lpar.append(e2.strip())
            lpre.append(epre)
        else:
            lpre.append('')
            lpar.append(e)
            fl += 1   # no header
    
    for e in lall:
        l2.append(e)
    
#     print(lall)
    pass

s = mReadFile('x15ta.txt')
l1 = s.split('\n')
l2 = []
mToParagraph(l1, l2)
mWriteFile('x15tb.txt', '\n'.join(l2))
print(len(l2))
# Out:
# 874

# %%
def mMakeList(count, prev='d', suf='a.txt'):
    l = []
    l = range(1,20)
    l = list(map(lambda x:  f'{x}' if x>9 else f'0{x}' , l))
    l = list(map(lambda x: f'{prev}{x}{suf}', l))
    return l

l = mMakeList(20)
for e in l:
    mWriteFile(e,'')
print(len(l))
# Out:
# 19

# %% [markdown]
# ## footer

# %% [markdown]
# ### figure
# 29-18, 29-5, 25-4, 20-6, 19-13, 19-5, 18-7, 18-4, 16-5, 16-1, 10-10, 9-4, 6-7, 6-2
#
#
# 11-16, 10-4, 2-24, 1-11

# %% [markdown]
# ### exchange
# ¦ => ######

# %% [markdown]
# ### append

# %%
s = '''
Part I Introduction to Networking
Chapter 1 Introduction to TCP/IP Networking
“Do I Know This Already?” Quiz
Foundation Topics
Perspectives on Networking
TCP/IP Networking Model
History Leading to TCP/IP
Overview of the TCP/IP Networking Model
TCP/IP Application Layer
HTTP Overview
HTTP Protocol Mechanisms
TCP/IP Transport Layer
TCP Error Recovery Basics
Same-Layer and Adjacent-Layer Interactions
TCP/IP Network Layer
Internet Protocol and the Postal Service
Internet Protocol Addressing Basics
IP Routing Basics
TCP/IP Data-Link and Physical Layers
Data Encapsulation Terminology
Names of TCP/IP Messages
OSI Networking Model and Terminology
Comparing OSI and TCP/IP Layer Names and Numbers
OSI Data Encapsulation Terminology
Chapter Review
Chapter 2 Fundamentals of Ethernet LANs
“Do I Know This Already?” Quiz
Foundation Topics
An Overview of LANs
Typical SOHO LANs
Typical Enterprise LANs
The Variety of Ethernet Physical Layer Standards
Consistent Behavior over All Links Using the Ethernet Data-Link Layer
Building Physical Ethernet LANs with UTP
Transmitting Data Using Twisted Pairs
Breaking Down a UTP Ethernet Link
UTP Cabling Pinouts for 10BASE-T and 100BASE-T
Straight-Through Cable Pinout
Choosing the Right Cable Pinouts
UTP Cabling Pinouts for 1000BASE-T
Building Physical Ethernet LANs with Fiber
Fiber Cabling Transmission Concepts
Using Fiber with Ethernet
Sending Data in Ethernet Networks
Ethernet Data-Link Protocols
Ethernet Addressing
Identifying Network Layer Protocols with the Ethernet Type Field
Error Detection with FCS
Sending Ethernet Frames with Switches and Hubs
Sending in Modern Ethernet LANs Using Full Duplex
Using Half Duplex with LAN Hubs
Chapter Review
Chapter 3 Fundamentals of WANs and IP Routing
“Do I Know This Already?” Quiz
Foundation Topics
Wide-Area Networks
Leased-Line WANs
Physical Details of Leased Lines
HDLC Data-Link Details of Leased Lines
How Routers Use a WAN Data Link
Ethernet as a WAN Technology
Ethernet WANs That Create a Layer 2 Service
How Routers Route IP Packets Using Ethernet Emulation
IP Routing
Network Layer Routing (Forwarding) Logic
Host Forwarding Logic: Send the Packet to the Default Router
R1 and R2’s Logic: Routing Data Across the Network
R3’s Logic: Delivering Data to the End Destination
How Network Layer Routing Uses LANs and WANs
How IP Addressing Helps IP Routing
Rules for Groups of IP Addresses (Networks and Subnets)
The IP Header
How IP Routing Protocols Help IP Routing
Other Network Layer Features
Using Names and the Domain Name System
The Address Resolution Protocol
ICMP Echo and the ping Command
Chapter Review
Part I Review
Part II Implementing Ethernet LANs
Chapter 4 Using the Command-Line Interface
“Do I Know This Already?” Quiz
Foundation Topics
Accessing the Cisco Catalyst Switch CLI
Cisco Catalyst Switches
Accessing the Cisco IOS CLI
Cabling the Console Connection
Accessing the CLI with Telnet and SSH
User and Enable (Privileged) Modes
Password Security for CLI Access from the Console
CLI Help Features
The debug and show Commands
Configuring Cisco IOS Software
Configuration Submodes and Contexts
Storing Switch Configuration Files
Copying and Erasing Configuration Files
Chapter Review
Chapter 5 Analyzing Ethernet LAN Switching
“Do I Know This Already?” Quiz
Foundation Topics
LAN Switching Concepts
Overview of Switching Logic
Forwarding Known Unicast Frames
Learning MAC Addresses
Flooding Unknown Unicast and Broadcast Frames
Avoiding Loops Using Spanning Tree Protocol
LAN Switching Summary
Verifying and Analyzing Ethernet Switching
Demonstrating MAC Learning
Switch Interfaces
Finding Entries in the MAC Address Table
Managing the MAC Address Table (Aging, Clearing)
MAC Address Tables with Multiple Switches
Chapter Review
Chapter 6 Configuring Basic Switch Management
“Do I Know This Already?” Quiz
Foundation Topics
Securing the Switch CLI
Securing User Mode and Privileged Mode with Simple Passwords
Securing User Mode Access with Local Usernames and Passwords
Securing User Mode Access with External Authentication Servers
Securing Remote Access with Secure Shell
Enabling IPv4 for Remote Access
Host and Switch IP Settings
Configuring IPv4 on a Switch
Configuring a Switch to Learn Its IP Address with DHCP
Verifying IPv4 on a Switch
Miscellaneous Settings Useful in the Lab
History Buffer Commands
The logging synchronous, exec-timeout, and no ip domain-lookup Commands
Chapter Review
Chapter 7 Configuring and Verifying Switch Interfaces
“Do I Know This Already?” Quiz
Foundation Topics
Configuring Switch Interfaces
Configuring Speed, Duplex, and Description
Configuring Multiple Interfaces with the interface range Command
Administratively Controlling Interface State with shutdown
Removing Configuration with the no Command
Autonegotiation
Autonegotiation Under Working Conditions
Autonegotiation Results When Only One Node Uses
Autonegotiation
Autonegotiation and LAN Hubs
Analyzing Switch Interface Status and Statistics
Interface Status Codes and Reasons for Nonworking States
Interface Speed and Duplex Issues
Common Layer 1 Problems on Working Interfaces
Chapter Review
Part II Review
Part III Implementing VLANs and STP
Chapter 8 Implementing Ethernet Virtual LANs
“Do I Know This Already?” Quiz
Foundation Topics
Virtual LAN Concepts
Creating Multiswitch VLANs Using Trunking
VLAN Tagging Concepts
The 802.1Q and ISL VLAN Trunking Protocols
Forwarding Data Between VLANs
The Need for Routing Between VLANs
Routing Packets Between VLANs with a Router
VLAN and VLAN Trunking Configuration and Verification
Creating VLANs and Assigning Access VLANs to an Interface
VLAN Configuration Example 1: Full VLAN Configuration
VLAN Configuration Example 2: Shorter VLAN Configuration
VLAN Trunking Protocol
VLAN Trunking Configuration
Implementing Interfaces Connected to Phones
Data and Voice VLAN Concepts
Data and Voice VLAN Configuration and Verification
Summary: IP Telephony Ports on Switches
Troubleshooting VLANs and VLAN Trunks
Access VLANs Undefined or Disabled
Mismatched Trunking Operational States
The Supported VLAN List on Trunks
Mismatched Native VLAN on a Trunk
Chapter Review
Chapter 9 Spanning Tree Protocol Concepts
“Do I Know This Already?” Quiz
Foundation Topics
STP and RSTP Basics
The Need for Spanning Tree
What Spanning Tree Does
How Spanning Tree Works
The STP Bridge ID and Hello BPDU
Electing the Root Switch
Choosing Each Switch’s Root Port
Choosing the Designated Port on Each LAN Segment
Configuring to Influence the STP Topology
Details Specific to STP (and Not RSTP)
STP Activity When the Network Remains Stable
STP Timers That Manage STP Convergence
Changing Interface States with STP
Rapid STP Concepts
Comparing STP and RSTP
RSTP and the Alternate (Root) Port Role
RSTP States and Processes
RSTP and the Backup (Designated) Port Role
RSTP Port Types
Optional STP Features
EtherChannel
PortFast
BPDU Guard
Chapter Review
Chapter 10 RSTP and EtherChannel Configuration
“Do I Know This Already?” Quiz
Foundation Topics
Understanding RSTP Through Configuration
The Need for Multiple Spanning Trees
STP Modes and Standards
The Bridge ID and System ID Extension
How Switches Use the Priority and System ID Extension
RSTP Methods to Support Multiple Spanning Trees
Other RSTP Configuration Options
Configuring Layer 2 EtherChannel
Configuring a Manual Layer 2 EtherChannel
Configuring Dynamic EtherChannels
Physical Interface Configuration and EtherChannels
EtherChannel Load Distribution
Configuration Options for EtherChannel Load Distribution
The Effects of the EtherChannel Load Distribution Algorithm
Chapter Review
Part III Review
Part IV IPv4 Addressing
Chapter 11 Perspectives on IPv4 Subnetting
“Do I Know This Already?” Quiz
Foundation Topics
Introduction to Subnetting
Subnetting Defined Through a Simple Example
Operational View Versus Design View of Subnetting
Analyze Subnetting and Addressing Needs
Rules About Which Hosts Are in Which Subnet
Determining the Number of Subnets
Determining the Number of Hosts per Subnet
One Size Subnet Fits All—Or Not
Defining the Size of a Subnet
One Size Subnet Fits All
Multiple Subnet Sizes (Variable-Length Subnet Masks)
One Mask for All Subnets, or More Than One
Make Design Choices
Choose a Classful Network
Public IP Networks
Growth Exhausts the Public IP Address Space
Private IP Networks
Choosing an IP Network During the Design Phase
Choose the Mask
Classful IP Networks Before Subnetting
Borrowing Host Bits to Create Subnet Bits
Choosing Enough Subnet and Host Bits
Example Design: 172.16.0.0, 200 Subnets, 200 Hosts
Masks and Mask Formats
Build a List of All Subnets
Plan the Implementation
Assigning Subnets to Different Locations
Choose Static and Dynamic Ranges per Subnet
Chapter Review
Chapter 12 Analyzing Classful IPv4 Networks
“Do I Know This Already?” Quiz
Foundation Topics
Classful Network Concepts
IPv4 Network Classes and Related Facts
The Number and Size of the Class A, B, and C Networks
Address Formats
Default Masks
Number of Hosts per Network
Deriving the Network ID and Related Numbers
Unusual Network IDs and Network Broadcast Addresses
Practice with Classful Networks
Practice Deriving Key Facts Based on an IP Address
Practice Remembering the Details of Address Classes
Chapter Review
Chapter 13 Analyzing Subnet Masks
“Do I Know This Already?” Quiz
Foundation Topics
Subnet Mask Conversion
Three Mask Formats
Converting Between Binary and Prefix Masks
Converting Between Binary and DDN Masks
Converting Between Prefix and DDN Masks
Practice Converting Subnet Masks
Identifying Subnet Design Choices Using Masks
Masks Divide the Subnet’s Addresses into Two Parts
Masks and Class Divide Addresses into Three Parts
Classless and Classful Addressing
Calculations Based on the IPv4 Address Format
Practice Analyzing Subnet Masks
Chapter Review
Chapter 14 Analyzing Existing Subnets
“Do I Know This Already?” Quiz
Foundation Topics
Defining a Subnet
An Example with Network 172.16.0.0 and Four Subnets
Subnet ID Concepts
Subnet Broadcast Address
Range of Usable Addresses
Analyzing Existing Subnets: Binary
Finding the Subnet ID: Binary
Finding the Subnet Broadcast Address: Binary
Binary Practice Problems
Shortcut for the Binary Process
Brief Note About Boolean Math
Finding the Range of Addresses
Analyzing Existing Subnets: Decimal
Analysis with Easy Masks
Predictability in the Interesting Octet
Finding the Subnet ID: Difficult Masks
Resident Subnet Example 1
Resident Subnet Example 2
Resident Subnet Practice Problems
Finding the Subnet Broadcast Address: Difficult Masks
Subnet Broadcast Example 1
Subnet Broadcast Example 2
Subnet Broadcast Address Practice Problems
Practice Analyzing Existing Subnets
A Choice: Memorize or Calculate
Chapter Review
Part IV Review
Part V IPv4 Routing
Chapter 15 Operating Cisco Routers
“Do I Know This Already?” Quiz
Foundation Topics
Installing Cisco Routers
Installing Enterprise Routers
Cisco Integrated Services Routers
Physical Installation
Installing SOHO Routers
Enabling IPv4 Support on Cisco Router Interfaces
Accessing the Router CLI
Router Interfaces
Interface Status Codes
Router Interface IP Addresses
Bandwidth and Clock Rate on Serial Interfaces
Router Auxiliary Port
Chapter Review
Chapter 16 Configuring IPv4 Addresses and Static Routes
“Do I Know This Already?” Quiz
Foundation Topics
IP Routing
IPv4 Routing Process Reference
An Example of IP Routing
Host Forwards the IP Packet to the Default Router (Gateway)
Routing Step 1: Decide Whether to Process the Incoming Frame
Routing Step 2: De-encapsulation of the IP Packet
Routing Step 3: Choosing Where to Forward the Packet
Routing Step 4: Encapsulating the Packet in a New Frame
Routing Step 5: Transmitting the Frame
Configuring IP Addresses and Connected Routes
Connected Routes and the ip address Command
The ARP Table on a Cisco Router
Configuring Static Routes
Static Network Routes
Static Host Routes
Floating Static Routes
Static Default Routes
Troubleshooting Static Routes
Troubleshooting Incorrect Static Routes That Appear in the IP Routing Table
The Static Route Does Not Appear in the IP Routing Table
The Correct Static Route Appears but Works Poorly
IP Forwarding with the Longest Prefix Match
Using show ip route to Find the Best Route
Using show ip route address to Find the Best Route
Interpreting the IP Routing Table
Chapter Review
Chapter 17 IP Routing in the LAN
“Do I Know This Already?” Quiz
Foundation Topics
VLAN Routing with Router 802.1Q Trunks
Configuring ROAS
Verifying ROAS
Troubleshooting ROAS
VLAN Routing with Layer 3 Switch SVIs
Configuring Routing Using Switch SVIs
Verifying Routing with SVIs
Troubleshooting Routing with SVIs
VLAN Routing with Layer 3 Switch Routed Ports
Implementing Routed Interfaces on Switches
Implementing Layer 3 EtherChannels
Troubleshooting Layer 3 EtherChannels
Chapter Review
Chapter 18 Troubleshooting IPv4 Routing
“Do I Know This Already?” Quiz
Foundation Topics
Problem Isolation Using the ping Command
Ping Command Basics
Strategies and Results When Testing with the ping Command
Testing Longer Routes from Near the Source of the Problem
Using Extended Ping to Test the Reverse Route
Testing LAN Neighbors with Standard Ping
Testing LAN Neighbors with Extended Ping
Testing WAN Neighbors with Standard Ping
Using Ping with Names and with IP Addresses
Problem Isolation Using the traceroute Command
traceroute Basics
How the traceroute Command Works
Standard and Extended traceroute
Telnet and SSH
Common Reasons to Use the IOS Telnet and SSH Client
IOS Telnet and SSH Examples
Chapter Review
Part V Review
Part VI OSPF
Chapter 19 Understanding OSPF Concepts
“Do I Know This Already?” Quiz
Foundation Topics
Comparing Dynamic Routing Protocol Features
Routing Protocol Functions
Interior and Exterior Routing Protocols
Comparing IGPs
IGP Routing Protocol Algorithms
Metrics
Other IGP Comparisons
Administrative Distance
OSPF Concepts and Operation
OSPF Overview
Topology Information and LSAs
Applying Dijkstra SPF Math to Find the Best Routes
Becoming OSPF Neighbors
The Basics of OSPF Neighbors
Meeting Neighbors and Learning Their Router ID
Exchanging the LSDB Between Neighbors
Fully Exchanging LSAs with Neighbors
Maintaining Neighbors and the LSDB
Using Designated Routers on Ethernet Links
Calculating the Best Routes with SPF
OSPF Areas and LSAs
OSPF Areas
How Areas Reduce SPF Calculation Time
(OSPFv2) Link-State Advertisements
Router LSAs Build Most of the Intra-Area Topology
Network LSAs Complete the Intra-Area Topology
Chapter Review
Chapter 20 Implementing OSPF
“Do I Know This Already?” Quiz
Foundation Topics
Implementing Single-Area OSPFv2
OSPF Single-Area Configuration
Wildcard Matching with the network Command
Verifying OSPF Operation
Verifying OSPF Configuration
Configuring the OSPF Router ID
Implementing Multiarea OSPF
Using OSPFv2 Interface Subcommands
OSPF Interface Configuration Example
Verifying OSPF Interface Configuration
Additional OSPFv2 Features
OSPF Passive Interfaces
OSPF Default Routes
OSPF Metrics (Cost)
Setting the Cost Directly
Setting the Cost Based on Interface and Reference Bandwidth
OSPF Load Balancing
Chapter Review
Chapter 21 OSPF Network Types and Neighbors
“Do I Know This Already?” Quiz
Foundation Topics
OSPF Network Types
The OSPF Broadcast Network Type
Verifying Operations with Network Type Broadcast
Configuring to Influence the DR/BDR Election
The OSPF Point-to-Point Network Type
OSPF Neighbor Relationships
OSPF Neighbor Requirements
Issues That Prevent Neighbor Adjacencies
Finding Area Mismatches
Finding Duplicate OSPF Router IDs
Finding OSPF Hello and Dead Timer Mismatches
Shutting Down the OSPF Process
Issues That Allow Adjacencies but Prevent IP Routes
Mismatched MTU Settings
Mismatched OSPF Network Types
Chapter Review
Part VI Review
Part VII IP Version 6
Chapter 22 Fundamentals of IP Version 6
“Do I Know This Already?” Quiz
Foundation Topics
Introduction to IPv6
The Historical Reasons for IPv6
The IPv6 Protocols
IPv6 Routing
IPv6 Routing Protocols
IPv6 Addressing Formats and Conventions
Representing Full (Unabbreviated) IPv6 Addresses
Abbreviating and Expanding IPv6 Addresses
Abbreviating IPv6 Addresses
Expanding Abbreviated IPv6 Addresses
Representing the Prefix Length of an Address
Calculating the IPv6 Prefix (Subnet ID)
Finding the IPv6 Prefix
Working with More-Difficult IPv6 Prefix Lengths
Chapter Review
Chapter 23 IPv6 Addressing and Subnetting
“Do I Know This Already?” Quiz
Foundation Topics
Global Unicast Addressing Concepts
Public and Private IPv6 Addresses
The IPv6 Global Routing Prefix
Address Ranges for Global Unicast Addresses
IPv6 Subnetting Using Global Unicast Addresses
Deciding Where IPv6 Subnets Are Needed
The Mechanics of Subnetting IPv6 Global Unicast Addresses
Listing the IPv6 Subnet Identifier
xxvi CCNA 200-301 Official Cert Guide, Volume 1
List All IPv6 Subnets
Assign Subnets to the Internetwork Topology
Assigning Addresses to Hosts in a Subnet
Unique Local Unicast Addresses
Subnetting with Unique Local IPv6 Addresses
The Need for Globally Unique Local Addresses
Chapter Review
Chapter 24 Implementing IPv6 Addressing on Routers
“Do I Know This Already?” Quiz
Foundation Topics
Implementing Unicast IPv6 Addresses on Routers
Static Unicast Address Configuration
Configuring the Full 128-Bit Address
Enabling IPv6 Routing
Verifying the IPv6 Address Configuration
Generating a Unique Interface ID Using Modified EUI-64
Dynamic Unicast Address Configuration
Special Addresses Used by Routers
Link-Local Addresses
Link-Local Address Concepts
Creating Link-Local Addresses on Routers
Routing IPv6 with Only Link-Local Addresses on an Interface
IPv6 Multicast Addresses
Reserved Multicast Addresses
Multicast Address Scopes
Solicited-Node Multicast Addresses
Miscellaneous IPv6 Addresses
Anycast Addresses
IPv6 Addressing Configuration Summary
Chapter Review
Chapter 25 Implementing IPv6 Routing
“Do I Know This Already?” Quiz
Foundation Topics
Connected and Local IPv6 Routes
Rules for Connected and Local Routes
Example of Connected IPv6 Routes
Examples of Local IPv6 Routes
Static IPv6 Routes
Static Routes Using the Outgoing Interface
Static Routes Using Next-Hop IPv6 Address
Example Static Route with a Global Unicast Next-Hop Address
Example Static Route with a Link-Local Next-Hop Address
Static Routes over Ethernet Links
Static Default Routes
Static IPv6 Host Routes
Floating Static IPv6 Routes
Troubleshooting Static IPv6 Routes
Troubleshooting Incorrect Static Routes That Appear in the IPv6 Routing Table
The Static Route Does Not Appear in the IPv6 Routing Table
The Neighbor Discovery Protocol
Discovering Neighbor Link Addresses with NDP NS and NA
Discovering Routers with NDP RS and RA
Using SLAAC with NDP RS and RA
Discovering Duplicate Addresses Using NDP NS and NA
NDP Summary
Chapter Review
Part VII Review
Part VIII Wireless LANs
Chapter 26 Fundamentals of Wireless Networks
“Do I Know This Already?” Quiz
Foundation Topics
Comparing Wired and Wireless Networks
Wireless LAN Topologies
Basic Service Set
Distribution System
Extended Service Set
Independent Basic Service Set
Other Wireless Topologies
Repeater
Workgroup Bridge
Outdoor Bridge
Mesh Network
RF Overview
Wireless Bands and Channels
APs and Wireless Standards
Chapter Review
Chapter 27 Analyzing Cisco Wireless Architectures
“Do I Know This Already?” Quiz
Foundation Topics
Autonomous AP Architecture
Cloud-based AP Architecture
Split-MAC Architectures
Comparing Wireless LAN Controller Deployments
Cisco AP Modes
Chapter Review
Chapter 28 Securing Wireless Networks
“Do I Know This Already?” Quiz
Foundation Topics
Anatomy of a Secure Connection
Authentication
Message Privacy
Message Integrity
Wireless Client Authentication Methods
Open Authentication
WEP
802.1x/EAP
LEAP
EAP-FAST
PEAP
EAP-TLS
Wireless Privacy and Integrity Methods
TKIP
CCMP
GCMP
WPA, WPA2, and WPA3
Chapter Review
Chapter 29 Building a Wireless LAN
“Do I Know This Already?” Quiz
Foundation Topics
Connecting a Cisco AP
Accessing a Cisco WLC
Connecting a Cisco WLC
Using WLC Ports
Using WLC Interfaces
Configuring a WLAN
Step 1. Configure a RADIUS Server
Step 2. Create a Dynamic Interface
Step 3. Create a New WLAN
Configuring WLAN Security
Configuring WLAN QoS
Configuring Advanced WLAN Settings
Finalizing WLAN Configuration
Chapter Review
Part VIII Review
Part IX Appendixes
'''

# %%
s = '''
## Part I Introduction to Networking
## Chapter 1 Introduction to TCP/IP Networking
### “Do I Know This Already?” Quiz
### Foundation Topics
### Perspectives on Networking
### TCP/IP Networking Model
#### History Leading to TCP/IP
#### Overview of the TCP/IP Networking Model
#### TCP/IP Application Layer
##### HTTP Overview
##### HTTP Protocol Mechanisms
#### TCP/IP Transport Layer
##### TCP Error Recovery Basics
##### Same-Layer and Adjacent-Layer Interactions
#### TCP/IP Network Layer
##### Internet Protocol and the Postal Service
##### Internet Protocol Addressing Basics
##### IP Routing Basics
#### TCP/IP Data-Link and Physical Layers
### Data Encapsulation Terminology
#### Names of TCP/IP Messages
#### OSI Networking Model and Terminology
##### Comparing OSI and TCP/IP Layer Names and Numbers
##### OSI Data Encapsulation Terminology
### Chapter Review
## Chapter 2 Fundamentals of Ethernet LANs
### “Do I Know This Already?” Quiz
### Foundation Topics
### An Overview of LANs
#### Typical SOHO LANs
#### Typical Enterprise LANs
#### The Variety of Ethernet Physical Layer Standards
#### Consistent Behavior over All Links Using the Ethernet Data-Link Layer
### Building Physical Ethernet LANs with UTP
#### Transmitting Data Using Twisted Pairs
#### Breaking Down a UTP Ethernet Link
#### UTP Cabling Pinouts for 10BASE-T and 100BASE-T
##### Straight-Through Cable Pinout
##### Choosing the Right Cable Pinouts
#### UTP Cabling Pinouts for 1000BASE-T
### Building Physical Ethernet LANs with Fiber
#### Fiber Cabling Transmission Concepts
#### Using Fiber with Ethernet
### Sending Data in Ethernet Networks
#### Ethernet Data-Link Protocols
##### Ethernet Addressing
##### Identifying Network Layer Protocols with the Ethernet Type Field
##### Error Detection with FCS
#### Sending Ethernet Frames with Switches and Hubs
##### Sending in Modern Ethernet LANs Using Full Duplex
##### Using Half Duplex with LAN Hubs
### Chapter Review
## Chapter 3 Fundamentals of WANs and IP Routing
### “Do I Know This Already?” Quiz
### Foundation Topics
### Wide-Area Networks
#### Leased-Line WANs
##### Physical Details of Leased Lines
##### HDLC Data-Link Details of Leased Lines
##### How Routers Use a WAN Data Link
#### Ethernet as a WAN Technology
##### Ethernet WANs That Create a Layer 2 Service
##### How Routers Route IP Packets Using Ethernet Emulation
### IP Routing
#### Network Layer Routing (Forwarding) Logic
##### Host Forwarding Logic: Send the Packet to the Default Router
##### R1 and R2’s Logic: Routing Data Across the Network
##### R3’s Logic: Delivering Data to the End Destination
#### How Network Layer Routing Uses LANs and WANs
#### How IP Addressing Helps IP Routing
##### Rules for Groups of IP Addresses (Networks and Subnets)
##### The IP Header
#### How IP Routing Protocols Help IP Routing
### Other Network Layer Features
#### Using Names and the Domain Name System
#### The Address Resolution Protocol
#### ICMP Echo and the ping Command
### Chapter Review
## Part I Review
## Part II Implementing Ethernet LANs
## Chapter 4 Using the Command-Line Interface
### “Do I Know This Already?” Quiz
### Foundation Topics
### Accessing the Cisco Catalyst Switch CLI
#### Cisco Catalyst Switches
#### Accessing the Cisco IOS CLI
##### Cabling the Console Connection
##### Accessing the CLI with Telnet and SSH
##### User and Enable (Privileged) Modes
##### Password Security for CLI Access from the Console
#### CLI Help Features
#### The debug and show Commands
### Configuring Cisco IOS Software
#### Configuration Submodes and Contexts
#### Storing Switch Configuration Files
#### Copying and Erasing Configuration Files
### Chapter Review
## Chapter 5 Analyzing Ethernet LAN Switching
### “Do I Know This Already?” Quiz
### Foundation Topics
### LAN Switching Concepts
#### Overview of Switching Logic
#### Forwarding Known Unicast Frames
#### Learning MAC Addresses
#### Flooding Unknown Unicast and Broadcast Frames
#### Avoiding Loops Using Spanning Tree Protocol
#### LAN Switching Summary
### Verifying and Analyzing Ethernet Switching
#### Demonstrating MAC Learning
#### Switch Interfaces
#### Finding Entries in the MAC Address Table
#### Managing the MAC Address Table (Aging, Clearing)
#### MAC Address Tables with Multiple Switches
### Chapter Review
## Chapter 6 Configuring Basic Switch Management
### “Do I Know This Already?” Quiz
### Foundation Topics
### Securing the Switch CLI
#### Securing User Mode and Privileged Mode with Simple Passwords
#### Securing User Mode Access with Local Usernames and Passwords
#### Securing User Mode Access with External Authentication Servers
#### Securing Remote Access with Secure Shell
### Enabling IPv4 for Remote Access
#### Host and Switch IP Settings
#### Configuring IPv4 on a Switch
#### Configuring a Switch to Learn Its IP Address with DHCP
#### Verifying IPv4 on a Switch
### Miscellaneous Settings Useful in the Lab
#### History Buffer Commands
#### The logging synchronous, exec-timeout, and no ip domain-lookup Commands
### Chapter Review
## Chapter 7 Configuring and Verifying Switch Interfaces
### “Do I Know This Already?” Quiz
### Foundation Topics
### Configuring Switch Interfaces
#### Configuring Speed, Duplex, and Description
#### Configuring Multiple Interfaces with the interface range Command
#### Administratively Controlling Interface State with shutdown
#### Removing Configuration with the no Command
#### Autonegotiation
#### Autonegotiation Under Working Conditions
##### Autonegotiation Results When Only One Node Uses
##### Autonegotiation
##### Autonegotiation and LAN Hubs
### Analyzing Switch Interface Status and Statistics
#### Interface Status Codes and Reasons for Nonworking States
#### Interface Speed and Duplex Issues
#### Common Layer 1 Problems on Working Interfaces
### Chapter Review
## Part II Review
## Part III Implementing VLANs and STP
## Chapter 8 Implementing Ethernet Virtual LANs
### “Do I Know This Already?” Quiz
### Foundation Topics
### Virtual LAN Concepts
#### Creating Multiswitch VLANs Using Trunking
##### VLAN Tagging Concepts
##### The 802.1Q and ISL VLAN Trunking Protocols
#### Forwarding Data Between VLANs
##### The Need for Routing Between VLANs
##### Routing Packets Between VLANs with a Router
### VLAN and VLAN Trunking Configuration and Verification
#### Creating VLANs and Assigning Access VLANs to an Interface
##### VLAN Configuration Example 1: Full VLAN Configuration
##### VLAN Configuration Example 2: Shorter VLAN Configuration
#### VLAN Trunking Protocol
#### VLAN Trunking Configuration
#### Implementing Interfaces Connected to Phones
##### Data and Voice VLAN Concepts
##### Data and Voice VLAN Configuration and Verification
##### Summary: IP Telephony Ports on Switches
### Troubleshooting VLANs and VLAN Trunks
#### Access VLANs Undefined or Disabled
#### Mismatched Trunking Operational States
#### The Supported VLAN List on Trunks
#### Mismatched Native VLAN on a Trunk
### Chapter Review
## Chapter 9 Spanning Tree Protocol Concepts
### “Do I Know This Already?” Quiz
### Foundation Topics
### STP and RSTP Basics
#### The Need for Spanning Tree
#### What Spanning Tree Does
#### How Spanning Tree Works
##### The STP Bridge ID and Hello BPDU
##### Electing the Root Switch
##### Choosing Each Switch’s Root Port
##### Choosing the Designated Port on Each LAN Segment
#### Configuring to Influence the STP Topology
### Details Specific to STP (and Not RSTP)
#### STP Activity When the Network Remains Stable
#### STP Timers That Manage STP Convergence
#### Changing Interface States with STP
### Rapid STP Concepts
#### Comparing STP and RSTP
#### RSTP and the Alternate (Root) Port Role
#### RSTP States and Processes
#### RSTP and the Backup (Designated) Port Role
#### RSTP Port Types
#### Optional STP Features
##### EtherChannel
##### PortFast
##### BPDU Guard
### Chapter Review
## Chapter 10 RSTP and EtherChannel Configuration
### “Do I Know This Already?” Quiz
### Foundation Topics
### Understanding RSTP Through Configuration
#### The Need for Multiple Spanning Trees
#### STP Modes and Standards
#### The Bridge ID and System ID Extension
#### How Switches Use the Priority and System ID Extension
#### RSTP Methods to Support Multiple Spanning Trees
#### Other RSTP Configuration Options
### Configuring Layer 2 EtherChannel
#### Configuring a Manual Layer 2 EtherChannel
#### Configuring Dynamic EtherChannels
#### Physical Interface Configuration and EtherChannels
#### EtherChannel Load Distribution
##### Configuration Options for EtherChannel Load Distribution
##### The Effects of the EtherChannel Load Distribution Algorithm
### Chapter Review
## Part III Review
## Part IV IPv4 Addressing
## Chapter 11 Perspectives on IPv4 Subnetting
### “Do I Know This Already?” Quiz
### Foundation Topics
### Introduction to Subnetting
#### Subnetting Defined Through a Simple Example
#### Operational View Versus Design View of Subnetting
### Analyze Subnetting and Addressing Needs
#### Rules About Which Hosts Are in Which Subnet
#### Determining the Number of Subnets
#### Determining the Number of Hosts per Subnet
#### One Size Subnet Fits All—Or Not
##### Defining the Size of a Subnet
##### One Size Subnet Fits All
##### Multiple Subnet Sizes (Variable-Length Subnet Masks)
##### One Mask for All Subnets, or More Than One
### Make Design Choices
#### Choose a Classful Network
##### Public IP Networks
##### Growth Exhausts the Public IP Address Space
##### Private IP Networks
##### Choosing an IP Network During the Design Phase
#### Choose the Mask
##### Classful IP Networks Before Subnetting
##### Borrowing Host Bits to Create Subnet Bits
##### Choosing Enough Subnet and Host Bits
##### Example Design: 172.16.0.0, 200 Subnets, 200 Hosts
##### Masks and Mask Formats
#### Build a List of All Subnets
### Plan the Implementation
#### Assigning Subnets to Different Locations
#### Choose Static and Dynamic Ranges per Subnet
### Chapter Review
## Chapter 12 Analyzing Classful IPv4 Networks
### “Do I Know This Already?” Quiz
### Foundation Topics
### Classful Network Concepts
#### IPv4 Network Classes and Related Facts
##### The Number and Size of the Class A, B, and C Networks
##### Address Formats
##### Default Masks
#### Number of Hosts per Network
#### Deriving the Network ID and Related Numbers
#### Unusual Network IDs and Network Broadcast Addresses
### Practice with Classful Networks
#### Practice Deriving Key Facts Based on an IP Address
#### Practice Remembering the Details of Address Classes
### Chapter Review
## Chapter 13 Analyzing Subnet Masks
### “Do I Know This Already?” Quiz
### Foundation Topics
### Subnet Mask Conversion
#### Three Mask Formats
#### Converting Between Binary and Prefix Masks
#### Converting Between Binary and DDN Masks
#### Converting Between Prefix and DDN Masks
#### Practice Converting Subnet Masks
### Identifying Subnet Design Choices Using Masks
#### Masks Divide the Subnet’s Addresses into Two Parts
#### Masks and Class Divide Addresses into Three Parts
#### Classless and Classful Addressing
#### Calculations Based on the IPv4 Address Format
#### Practice Analyzing Subnet Masks
### Chapter Review
## Chapter 14 Analyzing Existing Subnets
### “Do I Know This Already?” Quiz
### Foundation Topics
### Defining a Subnet
#### An Example with Network 172.16.0.0 and Four Subnets
#### Subnet ID Concepts
#### Subnet Broadcast Address
#### Range of Usable Addresses
### Analyzing Existing Subnets: Binary
#### Finding the Subnet ID: Binary
#### Finding the Subnet Broadcast Address: Binary
#### Binary Practice Problems
#### Shortcut for the Binary Process
#### Brief Note About Boolean Math
#### Finding the Range of Addresses
### Analyzing Existing Subnets: Decimal
#### Analysis with Easy Masks
#### Predictability in the Interesting Octet
#### Finding the Subnet ID: Difficult Masks
##### Resident Subnet Example 1
##### Resident Subnet Example 2
##### Resident Subnet Practice Problems
#### Finding the Subnet Broadcast Address: Difficult Masks
##### Subnet Broadcast Example 1
##### Subnet Broadcast Example 2
##### Subnet Broadcast Address Practice Problems
### Practice Analyzing Existing Subnets
#### A Choice: Memorize or Calculate
### Chapter Review
## Part IV Review
## Part V IPv4 Routing
## Chapter 15 Operating Cisco Routers
### “Do I Know This Already?” Quiz
### Foundation Topics
### Installing Cisco Routers
#### Installing Enterprise Routers
##### Cisco Integrated Services Routers
##### Physical Installation
#### Installing SOHO Routers
### Enabling IPv4 Support on Cisco Router Interfaces
#### Accessing the Router CLI
#### Router Interfaces
##### Interface Status Codes
##### Router Interface IP Addresses
##### Bandwidth and Clock Rate on Serial Interfaces
#### Router Auxiliary Port
### Chapter Review
## Chapter 16 Configuring IPv4 Addresses and Static Routes
### “Do I Know This Already?” Quiz
### Foundation Topics
### IP Routing
#### IPv4 Routing Process Reference
#### An Example of IP Routing
##### Host Forwards the IP Packet to the Default Router (Gateway)
##### Routing Step 1: Decide Whether to Process the Incoming Frame
##### Routing Step 2: De-encapsulation of the IP Packet
##### Routing Step 3: Choosing Where to Forward the Packet
##### Routing Step 4: Encapsulating the Packet in a New Frame
##### Routing Step 5: Transmitting the Frame
### Configuring IP Addresses and Connected Routes
#### Connected Routes and the ip address Command
#### The ARP Table on a Cisco Router
### Configuring Static Routes
#### Static Network Routes
#### Static Host Routes
#### Floating Static Routes
#### Static Default Routes
#### Troubleshooting Static Routes
##### Troubleshooting Incorrect Static Routes That Appear in the IP Routing Table
##### The Static Route Does Not Appear in the IP Routing Table
##### The Correct Static Route Appears but Works Poorly
### IP Forwarding with the Longest Prefix Match
#### Using show ip route to Find the Best Route
#### Using show ip route address to Find the Best Route
#### Interpreting the IP Routing Table
### Chapter Review
## Chapter 17 IP Routing in the LAN
### “Do I Know This Already?” Quiz
### Foundation Topics
### VLAN Routing with Router 802.1Q Trunks
#### Configuring ROAS
#### Verifying ROAS
#### Troubleshooting ROAS
### VLAN Routing with Layer 3 Switch SVIs
#### Configuring Routing Using Switch SVIs
#### Verifying Routing with SVIs
#### Troubleshooting Routing with SVIs
### VLAN Routing with Layer 3 Switch Routed Ports
#### Implementing Routed Interfaces on Switches
#### Implementing Layer 3 EtherChannels
#### Troubleshooting Layer 3 EtherChannels
### Chapter Review
## Chapter 18 Troubleshooting IPv4 Routing
### “Do I Know This Already?” Quiz
### Foundation Topics
### Problem Isolation Using the ping Command
#### Ping Command Basics
#### Strategies and Results When Testing with the ping Command
##### Testing Longer Routes from Near the Source of the Problem
##### Using Extended Ping to Test the Reverse Route
##### Testing LAN Neighbors with Standard Ping
##### Testing LAN Neighbors with Extended Ping
##### Testing WAN Neighbors with Standard Ping
#### Using Ping with Names and with IP Addresses
### Problem Isolation Using the traceroute Command
#### traceroute Basics
##### How the traceroute Command Works
##### Standard and Extended traceroute
### Telnet and SSH
#### Common Reasons to Use the IOS Telnet and SSH Client
#### IOS Telnet and SSH Examples
### Chapter Review
## Part V Review
## Part VI OSPF
## Chapter 19 Understanding OSPF Concepts
### “Do I Know This Already?” Quiz
### Foundation Topics
### Comparing Dynamic Routing Protocol Features
#### Routing Protocol Functions
#### Interior and Exterior Routing Protocols
#### Comparing IGPs
##### IGP Routing Protocol Algorithms
##### Metrics
##### Other IGP Comparisons
#### Administrative Distance
### OSPF Concepts and Operation
#### OSPF Overview
##### Topology Information and LSAs
##### Applying Dijkstra SPF Math to Find the Best Routes
#### Becoming OSPF Neighbors
##### The Basics of OSPF Neighbors
##### Meeting Neighbors and Learning Their Router ID
#### Exchanging the LSDB Between Neighbors
##### Fully Exchanging LSAs with Neighbors
##### Maintaining Neighbors and the LSDB
##### Using Designated Routers on Ethernet Links
#### Calculating the Best Routes with SPF
### OSPF Areas and LSAs
#### OSPF Areas
#### How Areas Reduce SPF Calculation Time
#### (OSPFv2) Link-State Advertisements
##### Router LSAs Build Most of the Intra-Area Topology
##### Network LSAs Complete the Intra-Area Topology
### Chapter Review
### Chapter 20 Implementing OSPF
### “Do I Know This Already?” Quiz
### Foundation Topics
#### Implementing Single-Area OSPFv2
#### OSPF Single-Area Configuration
#### Wildcard Matching with the network Command
#### Verifying OSPF Operation
#### Verifying OSPF Configuration
#### Configuring the OSPF Router ID
#### Implementing Multiarea OSPF
### Using OSPFv2 Interface Subcommands
#### OSPF Interface Configuration Example
##### Verifying OSPF Interface Configuration
### Additional OSPFv2 Features
#### OSPF Passive Interfaces
#### OSPF Default Routes
#### OSPF Metrics (Cost)
##### Setting the Cost Directly
##### Setting the Cost Based on Interface and Reference Bandwidth
#### OSPF Load Balancing
### Chapter Review
## Chapter 21 OSPF Network Types and Neighbors
### “Do I Know This Already?” Quiz
### Foundation Topics
### OSPF Network Types
#### The OSPF Broadcast Network Type
##### Verifying Operations with Network Type Broadcast
##### Configuring to Influence the DR/BDR Election
#### The OSPF Point-to-Point Network Type
### OSPF Neighbor Relationships
#### OSPF Neighbor Requirements
#### Issues That Prevent Neighbor Adjacencies
##### Finding Area Mismatches
##### Finding Duplicate OSPF Router IDs
##### Finding OSPF Hello and Dead Timer Mismatches
##### Shutting Down the OSPF Process
#### Issues That Allow Adjacencies but Prevent IP Routes
##### Mismatched MTU Settings
##### Mismatched OSPF Network Types
### Chapter Review
## Part VI Review
## Part VII IP Version 6
## Chapter 22 Fundamentals of IP Version 6
### “Do I Know This Already?” Quiz
### Foundation Topics
### Introduction to IPv6
#### The Historical Reasons for IPv6
#### The IPv6 Protocols
#### IPv6 Routing
#### IPv6 Routing Protocols
### IPv6 Addressing Formats and Conventions
#### Representing Full (Unabbreviated) IPv6 Addresses
#### Abbreviating and Expanding IPv6 Addresses
##### Abbreviating IPv6 Addresses
##### Expanding Abbreviated IPv6 Addresses
#### Representing the Prefix Length of an Address
#### Calculating the IPv6 Prefix (Subnet ID)
#### Finding the IPv6 Prefix
#### Working with More-Difficult IPv6 Prefix Lengths
### Chapter Review
## Chapter 23 IPv6 Addressing and Subnetting
### “Do I Know This Already?” Quiz
### Foundation Topics
### Global Unicast Addressing Concepts
#### Public and Private IPv6 Addresses
#### The IPv6 Global Routing Prefix
#### Address Ranges for Global Unicast Addresses
#### IPv6 Subnetting Using Global Unicast Addresses
##### Deciding Where IPv6 Subnets Are Needed
##### The Mechanics of Subnetting IPv6 Global Unicast Addresses
##### Listing the IPv6 Subnet Identifier
##### xxvi CCNA 200-301 Official Cert Guide, Volume 1
##### List All IPv6 Subnets
##### Assign Subnets to the Internetwork Topology
#### Assigning Addresses to Hosts in a Subnet
### Unique Local Unicast Addresses
#### Subnetting with Unique Local IPv6 Addresses
#### The Need for Globally Unique Local Addresses
### Chapter Review
## Chapter 24 Implementing IPv6 Addressing on Routers
### “Do I Know This Already?” Quiz
### Foundation Topics
### Implementing Unicast IPv6 Addresses on Routers
#### Static Unicast Address Configuration
##### Configuring the Full 128-Bit Address
##### Enabling IPv6 Routing
##### Verifying the IPv6 Address Configuration
##### Generating a Unique Interface ID Using Modified EUI-64
#### Dynamic Unicast Address Configuration
### Special Addresses Used by Routers
#### Link-Local Addresses
##### Link-Local Address Concepts
##### Creating Link-Local Addresses on Routers
##### Routing IPv6 with Only Link-Local Addresses on an Interface
##### IPv6 Multicast Addresses
##### Reserved Multicast Addresses
##### Multicast Address Scopes
##### Solicited-Node Multicast Addresses
#### Miscellaneous IPv6 Addresses
#### Anycast Addresses
#### IPv6 Addressing Configuration Summary
### Chapter Review
## Chapter 25 Implementing IPv6 Routing
### “Do I Know This Already?” Quiz
### Foundation Topics
### Connected and Local IPv6 Routes
#### Rules for Connected and Local Routes
#### Example of Connected IPv6 Routes
#### Examples of Local IPv6 Routes
### Static IPv6 Routes
#### Static Routes Using the Outgoing Interface
#### Static Routes Using Next-Hop IPv6 Address
##### Example Static Route with a Global Unicast Next-Hop Address
##### Example Static Route with a Link-Local Next-Hop Address
##### Static Routes over Ethernet Links
#### Static Default Routes
#### Static IPv6 Host Routes
#### Floating Static IPv6 Routes
#### Troubleshooting Static IPv6 Routes
##### Troubleshooting Incorrect Static Routes That Appear in the IPv6 Routing Table
##### The Static Route Does Not Appear in the IPv6 Routing Table
### The Neighbor Discovery Protocol
#### Discovering Neighbor Link Addresses with NDP NS and NA
#### Discovering Routers with NDP RS and RA
#### Using SLAAC with NDP RS and RA
#### Discovering Duplicate Addresses Using NDP NS and NA
#### NDP Summary
### Chapter Review
## Part VII Review
## Part VIII Wireless LANs
## Chapter 26 Fundamentals of Wireless Networks
### “Do I Know This Already?” Quiz
### Foundation Topics
### Comparing Wired and Wireless Networks
### Wireless LAN Topologies
#### Basic Service Set
#### Distribution System
#### Extended Service Set
#### Independent Basic Service Set
### Other Wireless Topologies
#### Repeater
#### Workgroup Bridge
#### Outdoor Bridge
#### Mesh Network
### RF Overview
#### Wireless Bands and Channels
#### APs and Wireless Standards
### Chapter Review
## Chapter 27 Analyzing Cisco Wireless Architectures
### “Do I Know This Already?” Quiz
### Foundation Topics
### Autonomous AP Architecture
### Cloud-based AP Architecture
### Split-MAC Architectures
### Comparing Wireless LAN Controller Deployments
#### Cisco AP Modes
### Chapter Review
## Chapter 28 Securing Wireless Networks
### “Do I Know This Already?” Quiz
### Foundation Topics
### Anatomy of a Secure Connection
#### Authentication
#### Message Privacy
#### Message Integrity
### Wireless Client Authentication Methods
#### Open Authentication
#### WEP
#### 802.1x/EAP
##### LEAP
##### EAP-FAST
##### PEAP
##### EAP-TLS
### Wireless Privacy and Integrity Methods
#### TKIP
#### CCMP
#### GCMP
### WPA, WPA2, and WPA3
### Chapter Review
## Chapter 29 Building a Wireless LAN
### “Do I Know This Already?” Quiz
### Foundation Topics
### Connecting a Cisco AP
### Accessing a Cisco WLC
### Connecting a Cisco WLC
#### Using WLC Ports
#### Using WLC Interfaces
### Configuring a WLAN
#### Step 1. Configure a RADIUS Server
#### Step 2. Create a Dynamic Interface
#### Step 3. Create a New WLAN
#### Configuring WLAN Security
#### Configuring WLAN QoS
#### Configuring Advanced WLAN Settings
#### Finalizing WLAN Configuration
### Chapter Review
## Part VIII Review
## Part IX Appendixes
'''

# %%
s = '''
111
222
333
44
555
666
'''
sc = '''
222
444
666
'''

# %%
def mChList(l, lc, l2):
    n = 0
    nstr = 0
    n2str = 0
    n3str = 0
    kc = 0
    for e in l:
        match1 = re.search(lc[kc], e)
        match2 = re.search(lc[kc][:-1], e)
        if kc < len(lc)-1:
            if match1:
                kc += 1
                n += 1
                n2str = nstr 
        else:
            break
        if match2:
            n3str = nstr
        nstr += 1
    print('quantity =', n, n2str, n3str)
    pass

l = []
mList(s, l)
lc = []
mList(sc, lc)
lc = list(filter(lambda x:len(x.strip())>0, lc))
l2 = []
mChList(l, lc, l2)
print(l)
print(lc)
# Out:
# quantity = 1 2 4
# ['', '111', '222', '333', '44', '555', '666', '']
# ['222', '444', '666']

# %%
s = '''
implemented by Spanning
Tree Protocol (STP). Without STP, any flooded frames would loop for an indefinite period of
Technet24
||||||||||||||||||||
||||||||||||||||||||
5
Chapter 5: Analyzing Ethernet LAN Switching 115
time in Ethernet networks with physically redundant links. To prevent looping frames, STP

'''

# %%
def mDelMid(l1, lm, l2, l3):
    '''
    l1 in, lm [1,2], l2 out, l3 out cut
    '''
    l21 = []
    l31 = []
    e0 = l1[0]
    fl = 0
    lt = []
    for i in range(1, len(l1)):
        e = l1[i]
        match1 = re.search(lm[0], e)
        match2 = re.search(lm[1], e)
        if fl == 0:
            l21.append(e)
        if match1:
            fl += 1
        if fl>0:
            lt.append(e)
        if match2:
            l21.append(e)
            l31 += lt
            lt = []
            fl = 0
    for e in l31:
#         print(e)
        pass
    for e in l21[:1000]:
#         print(e)
        pass
    pass

s = mReadFile('x15cla.txt')
l1 = []
mList(s, l1)
print(len(l1))
l2 = []
l3 = []
mDelMid(l1, ['^Table \d\d?-\d\d? [A-Z]', '^Table end.'],
       l2, l3)
# Out:
# 43401

# %% [markdown]
# ## examples
# - вырезка examples
# - работаем с 'x15cla.txt' пишем в 'x15clc.txt'
# - вставка 'Examples end.' перед строкой из 'x15exc.txt'
#
# - examples сохраняется в 'x15exd.txt'

# %%
import re

def mCutMid(l1, lm1, lm2, l2, l3):
    
    
    pass

l1 = []
s = mReadFile('x15cla.txt')
mList(s, l1)
l1.append('11')
lm1 = []
lm1 = list(filter(lambda x: 
re.search('^Example \d\d?-\d\d? [A-Z]', x), l1))
lm2 = []
s = mReadFile('x15exc.txt')
mList(s, lm2)
lm2 = list(filter(lambda x: len(x.strip())>0, lm2))

e0 = l1[0]
fl = 0
k1 = 0
k2 = 0
str0 = ''

c1 = len(lm1)
c2 = len(lm2)
l3 = []
l2 = []
for i in range(min(c1, c2)):
#     print(lm1[i])
#     print(lm2[i])
    pass
lt = []
for i in range(1, len(l1)):
    e = l1[i]
    match1 = re.search(lm1[k1][:20], e0)
    match2 = None
    if match1:
        fl += 1
        l2.append(e0)
#         print(e0)
    if fl > 0:
        lt.append(e0)
        fl += 1
        match2 = re.search(lm2[k1][:20], e)
        if match2:
            if k1 < min(len(lm1), len(lm2))-1:
                k1 += 1
#             lt.append(e)
            l2.append('Example end.')
            l3 += lt
            lt = []
            fl = 0
    else:
        l2.append(e0)
    e0 = e


mWriteFile('x15exd.txt', '\n'.join(l3))    
mWriteFile('x15clc.txt', '\n'.join(l2))    
    

print(len(l2), len(lm1),len(lm2), lm2[:2])
# mCutMid(l1, lm1, lm2, l2, l3)
# Out:
# 41261 148 148 ['NOTE', 'Working from top to bottom, note that the first configuration command listed by the show']

# %%
l1 = []
s = mReadFile('x15cla.txt')
mList(s, l1)
lm1 = []
lm1 = list(filter(lambda x: 
re.search('^Example \d\d?-\d\d? [A-Z]', x), l1))
lm2 = []
s = mReadFile('x15exc.txt')
mList(s, lm2)
lm2 = list(filter(lambda x: len(x.strip())>0, lm2))

e0 = l1[0]
fl = 0
k1 = 0
k2 = 0
str0 = ''

c1 = len(lm1)
c2 = len(lm2)
for i in range(min(c1, c2, 2)):
    print(lm1[i])
    print(lm2[i])
    pass
# Out:
# Example 4-1 Example of Privileged Mode Commands Being Rejected in User Mode
# NOTE
# Example 4-2 Nondefault Basic Configuration
# Working from top to bottom, note that the first configuration command listed by the show
